# %%
from typing import Iterator
import numpy as np
import os
import torch
from problog.logic import Term, Constant, list2term
from deepproblog.dataset import Dataset
from deepproblog.query import Query
import matplotlib.pyplot as plt
import sys

# %%
import torch
import torch.nn as nn

class MNIST_SudokuNet(nn.Module):
    def __init__(self):
        super(MNIST_SudokuNet, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 6, 5),
            nn.MaxPool2d(2, 2),
            nn.ReLU(True),
            nn.Conv2d(6, 16, 5),
            nn.MaxPool2d(2, 2),
            nn.ReLU(True),
        )
        # Only 9 outputs now
        self.classifier = nn.Sequential(
            nn.Linear(16*4*4, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 9),   # 9 classes => digits 1..9
            nn.Softmax(dim=1),
        )

    def forward(self, x):
        x = self.encoder(x)                # 1×28×28 -> ...
        x = x.view(-1, 16 * 4 * 4)         
        x = self.classifier(x)             # -> 9 outputs 
        return x

# %%
class SudokuPuzzleDataset(Dataset):
    def __init__(self, subset: str, puzzle_path: str, solution_path: str):
        self.subset = subset
        self.puzzle_files = sorted([f for f in os.listdir(puzzle_path) if f.endswith('.npy')])
        self.puzzles = []
        for fn in self.puzzle_files:
            puzzle = np.load(os.path.join(puzzle_path, fn), allow_pickle=True)
            # Keep puzzle[i][j] == None if empty
            # If not None, we treat it as a 28×28 image
            #   and normalize it (1..255 => /255)
            for i in range(9):
                for j in range(9):
                    if puzzle[i][j] is not None:
                        puzzle[i][j] = puzzle[i][j].astype(np.float32)/255.0
            self.puzzles.append(puzzle)

        self.solution_files = sorted(f for f in os.listdir(solution_path) if f.endswith('.npy'))
        self.solutions = []
        for fn in self.solution_files:
            solution = np.load(os.path.join(solution_path, fn), allow_pickle=True)
            self.solutions.append(solution)

    def __len__(self):
        return len(self.puzzles)

    def __getitem__(self, item):
        """
        For the Prolog side, we only need to retrieve the actual image data 
        if the cell is not None. We'll handle that in 'to_query' as well.
        """
        # This method is used by the DeepProbLog model to fetch the image.
        # We'll just return a single cell's tensor to illustrate 
        # (not typically used if you do full puzzle queries).
        puzzle_index, row, col = item
        cell = self.puzzles[int(puzzle_index)][int(row)][int(col)]
        if cell is None:
            # Not returning an image for None cells
            raise ValueError("Attempted to retrieve an image for a None cell.")
        # print
        return torch.tensor(cell).unsqueeze(0)  # 1×28×28

    def to_query(self, index: int) -> Query:
        """
        Construct a query puzzle_solve(...) for the entire 9×9 puzzle.
        We'll produce a 9×9 list-of-lists:
          - If puzzle[i][j] is None => use Constant('none')
          - Else => Term('tensor', Term(self.subset, Constant(unique_id)))
        """
        puzzle = self.puzzles[index]
        # We'll create 9 rows of terms
        row_list_terms = []

        for i in range(9):
            col_terms = []
            for j in range(9):
                if puzzle[i][j] is None:
                    # Just an atom 'none'
                    col_terms.append(Constant('none'))
                else:
                    # A reference to the network input
                    image_term = Term("tensor", Term(self.subset, Constant(index), Constant(i), Constant(j)))
                    label = Constant(self.solutions[index][i][j])
                    col_terms.append(Term("digit", image_term, label))

            row_list_terms.append(list2term(col_terms))

        # puzzle_solve( [[...],[...],...] )
        query_term = Term("puzzle_solve", list2term(row_list_terms))
        # print("Query constructed", query_term)
        return Query(query_term)

# %%
import torch
from deepproblog.model import Model
from deepproblog.network import Network
from deepproblog.engines import ExactEngine
from deepproblog.dataset import DataLoader
from deepproblog.train import train_model

# %%
network = MNIST_SudokuNet()
net = Network(network, "mnist_net", batching=True)
net.optimizer = torch.optim.Adam(network.parameters(), lr=1e-3)

# 2) Create the model from 'sudoku_no_clpfd.pl'
model = Model("prolog3.pl", [net])
model.set_engine(ExactEngine(model))

# 3) Load the dataset
train_data = SudokuPuzzleDataset("train", "../../mnist_sudoku_generator/dataset/images/puzzles/train", "../../mnist_sudoku_generator/dataset/arrays/puzzles/train")
model.add_tensor_source("train", train_data)

loader = DataLoader(train_data, batch_size=1, shuffle=True)
train_model(model, loader, 1, log_iter=1)
# Out:
# Training  for 1 epoch(s)
# Epoch 1
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[none, digit(tensor(train(1904,0,1)),8), digit(tensor(train(1904,0,2)),6), digit(tensor(train(1904,0,3)),3), none, digit(tensor(train(1904,0,5)),1), none, none, digit(tensor(train(1904,0,8)),9)], [none, digit(tensor(train(1904,1,1)),4), digit(tensor(train(1904,1,2)),2), none, digit(tensor(train(1904,1,4)),5), digit(tensor(train(1904,1,5)),7), digit(tensor(train(1904,1,6)),8), none, none], [digit(tensor(train(1904,2,0)),5), none, none, digit(tensor(train(1904,2,3)),9), digit(tensor(train(1904,2,4)),4), digit(tensor(train(1904,2,5)),8), none, digit(tensor(train(1904,2,7)),6), digit(tensor(train(1904,2,8)),7)], [digit(tensor(train(1904,3,0)),4), digit(tensor(train(1904,3,1)),5), digit(tensor(train(1904,3,2)),7), none, digit(tensor(train(1904,3,4)),1), digit(tensor(train(1904,3,5)),3), digit(tensor(train(1904,3,6)),9), none, digit(tensor(train(1904,3,8)),6)], [digit(tensor(train(1904,4,0)),8), none, none, none, none, digit(tensor(train(1904,4,5)),6), digit(tensor(train(1904,4,6)),1), none, digit(tensor(train(1904,4,8)),4)], [digit(tensor(train(1904,5,0)),2), digit(tensor(train(1904,5,1)),6), none, none, none, none, digit(tensor(train(1904,5,6)),3), digit(tensor(train(1904,5,7)),7), none], [digit(tensor(train(1904,6,0)),6), none, none, digit(tensor(train(1904,6,3)),7), none, none, digit(tensor(train(1904,6,6)),5), none, none], [digit(tensor(train(1904,7,0)),3), none, none, none, digit(tensor(train(1904,7,4)),6), none, none, none, none], [digit(tensor(train(1904,8,0)),1), none, digit(tensor(train(1904,8,2)),4), none, none, digit(tensor(train(1904,8,5)),5), digit(tensor(train(1904,8,6)),6), none, digit(tensor(train(1904,8,8)),2)]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, 6, 3, X2, 1, X3, X4, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 4, 2, X2, 5, 7, 8, X3, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, X1, X2, 9, 4, 8, X3, 6, 7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 5, 7, X1, 1, 3, 9, X2, 6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, X1, X2, X3, X4, 6, 1, X5, 4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[2, 6, X1, X2, X3, X4, 3, 7, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[6, X1, X2, 7, X3, X4, 5, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[3, X1, X2, X3, 6, X4, X5, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, X1, 4, X2, X3, 5, 6, X4, 2]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[X1, 8, 6, 3, X2, 1, X3, X4, 9], [X5, 4, 2, X6, 5, 7, 8, X7, X8], [5, X9, X10, 9, 4, 8, X11, 6, 7], [4, 5, 7, X12, 1, 3, 9, X13, 6], [8, X14, X15, X16, X17, 6, 1, X18, 4], [2, 6, X19, X20, X21, X22, 3, 7, X23], [6, X24, X25, 7, X26, X27, 5, X28, X29], [3, X30, X31, X32, 6, X33, X34, X35, X36], [1, X37, 4, X38, X39, 5, 6, X40, 2]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[X1, 8, 6, 3, X2, 1, X3, X4, 9], [X5, 4, 2, X6, 5, 7, 8, X7, X8], [5, X9, X10, 9, 4, 8, X11, 6, 7], [4, 5, 7, X12, 1, 3, 9, X13, 6], [8, X14, X15, X16, X17, 6, 1, X18, 4], [2, 6, X19, X20, X21, X22, 3, 7, X23], [6, X24, X25, 7, X26, X27, 5, X28, X29], [3, X30, X31, X32, 6, X33, X34, X35, X36], [1, X37, 4, X38, X39, 5, 6, X40, 2]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[X1, 8, 6, 3, X2, 1, X3, X4, 9], [X5, 4, 2, X6, 5, 7, 8, X7, X8], [5, X9, X10, 9, 4, 8, X11, 6, 7], [4, 5, 7, X12, 1, 3, 9, X13, 6], [8, X14, X15, X16, X17, 6, 1, X18, 4], [2, 6, X19, X20, X21, X22, 3, 7, X23], [6, X24, X25, 7, X26, X27, 5, X28, X29], [3, X30, X31, X32, 6, X33, X34, X35, X36], [1, X37, 4, X38, X39, 5, 6, X40, 2]]]
# 1 "transpose/2: Called with Ls=~w" [[[X1, 8, 6, 3, X2, 1, X3, X4, 9], [X5, 4, 2, X6, 5, 7, 8, X7, X8], [5, X9, X10, 9, 4, 8, X11, 6, 7], [4, 5, 7, X12, 1, 3, 9, X13, 6], [8, X14, X15, X16, X17, 6, 1, X18, 4], [2, 6, X19, X20, X21, X22, 3, 7, X23], [6, X24, X25, 7, X26, X27, 5, X28, X29], [3, X30, X31, X32, 6, X33, X34, X35, X36], [1, X37, 4, X38, X39, 5, 6, X40, 2]]]
# 1 "transpose/2: Transposed ~w" [[[X1, X2, 5, 4, 8, 2, 6, 3, 1], [8, 4, X3, 5, X4, 6, X5, X6, X7], [6, 2, X8, 7, X9, X10, X11, X12, 4], [3, X13, 9, X14, X15, X16, 7, X17, X18], [X19, 5, 4, 1, X20, X21, X22, 6, X23], [1, 7, 8, 3, 6, X24, X25, X26, 5], [X27, 8, X28, 9, 1, 3, 5, X29, 6], [X30, X31, 6, X32, X33, 7, X34, X35, X36], [9, X37, 7, 6, 4, X38, X39, X40, 2]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[X1, 8, 6, 3, X2, 1, X3, X4, 9], [[X5, 4, 2, X6, 5, 7, 8, X7, X8], [5, X9, X10, 9, 4, 8, X11, 6, 7], [4, 5, 7, X12, 1, 3, 9, X13, 6], [8, X14, X15, X16, X17, 6, 1, X18, 4], [2, 6, X19, X20, X21, X22, 3, 7, X23], [6, X24, X25, 7, X26, X27, 5, X28, X29], [3, X30, X31, X32, 6, X33, X34, X35, X36], [1, X37, 4, X38, X39, 5, 6, X40, 2]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[7, 8, 6, 3, 2, 1, 4, 5, 9]]
# 1 "" [[9, 4, 2, 6, 5, 7, 8, 1, 3]]
# 1 "" [[5, 1, 3, 9, 4, 8, 2, 6, 7]]
# 1 "" [[4, 5, 7, 2, 1, 3, 9, 8, 6]]
# 1 "" [[8, 3, 9, 5, 7, 6, 1, 2, 4]]
# 1 "" [[2, 6, 1, 4, 8, 9, 3, 7, 5]]
# 1 "" [[6, 2, 8, 7, 3, 4, 5, 9, 1]]
# 1 "" [[3, 9, 5, 1, 6, 2, 7, 4, 8]]
# 1 "" [[1, 7, 4, 8, 9, 5, 6, 3, 2]]
# 1 "printing solution" []
# 1 "" [[7, 8, 6, 3, 2, 1, 4, 5, 9]]
# 1 "" [[9, 4, 2, 6, 5, 7, 8, 1, 3]]
# 1 "" [[5, 1, 3, 9, 4, 8, 2, 6, 7]]
# 1 "" [[4, 5, 7, 2, 1, 3, 9, 8, 6]]
# 1 "" [[8, 3, 9, 5, 7, 6, 1, 2, 4]]
# 1 "" [[2, 6, 1, 4, 8, 9, 3, 7, 5]]
# 1 "" [[6, 2, 8, 7, 9, 4, 5, 3, 1]]
# 1 "" [[3, 9, 5, 1, 6, 2, 7, 4, 8]]
# 1 "" [[1, 7, 4, 8, 3, 5, 6, 9, 2]]
# 1 "printing solution" []
# 1 "" [[7, 8, 6, 3, 2, 1, 4, 5, 9]]
# 1 "" [[9, 4, 2, 6, 5, 7, 8, 1, 3]]
# 1 "" [[5, 1, 3, 9, 4, 8, 2, 6, 7]]
# 1 "" [[4, 5, 7, 2, 1, 3, 9, 8, 6]]
# 1 "" [[8, 3, 9, 5, 7, 6, 1, 2, 4]]
# 1 "" [[2, 6, 1, 4, 8, 9, 3, 7, 5]]
# 1 "" [[6, 9, 8, 7, 3, 2, 5, 4, 1]]
# 1 "" [[3, 2, 5, 1, 6, 4, 7, 9, 8]]
# 1 "printing solution" []
# 1 "" [[7, 8, 6, 3, 2, 1, 4, 5, 9]]
# 1 "" [[9, 4, 2, 6, 5, 7, 8, 3, 1]]
# 1 "" [[5, 1, 3, 9, 4, 8, 2, 6, 7]]
# 1 "" [[4, 5, 7, 2, 1, 3, 9, 8, 6]]
# 1 "" [[8, 3, 9, 5, 7, 6, 1, 2, 4]]
# 1 "" [[2, 6, 1, 4, 8, 9, 3, 7, 5]]
# 1 "" [[6, 2, 8, 7, 9, 4, 5, 1, 3]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# Iteration:  2 	s:190.1980 	Average Loss:  27.63102149963379
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[none, digit(tensor(train(5325,0,1)),1), none, none, digit(tensor(train(5325,0,4)),7), none, none, none, none], [none, none, digit(tensor(train(5325,1,2)),9), digit(tensor(train(5325,1,3)),3), digit(tensor(train(5325,1,4)),6), digit(tensor(train(5325,1,5)),1), none, digit(tensor(train(5325,1,7)),2), digit(tensor(train(5325,1,8)),5)], [none, none, none, digit(tensor(train(5325,2,3)),8), digit(tensor(train(5325,2,4)),5), digit(tensor(train(5325,2,5)),9), none, digit(tensor(train(5325,2,7)),3), none], [digit(tensor(train(5325,3,0)),5), digit(tensor(train(5325,3,1)),8), none, none, none, none, digit(tensor(train(5325,3,6)),3), digit(tensor(train(5325,3,7)),1), digit(tensor(train(5325,3,8)),9)], [none, none, none, none, none, digit(tensor(train(5325,4,5)),4), digit(tensor(train(5325,4,6)),2), none, none], [digit(tensor(train(5325,5,0)),9), digit(tensor(train(5325,5,1)),2), digit(tensor(train(5325,5,2)),6), digit(tensor(train(5325,5,3)),1), none, none, digit(tensor(train(5325,5,6)),5), none, none], [none, none, digit(tensor(train(5325,6,2)),3), none, digit(tensor(train(5325,6,4)),8), digit(tensor(train(5325,6,5)),5), digit(tensor(train(5325,6,6)),4), digit(tensor(train(5325,6,7)),9), digit(tensor(train(5325,6,8)),1)], [digit(tensor(train(5325,7,0)),4), digit(tensor(train(5325,7,1)),5), digit(tensor(train(5325,7,2)),2), none, digit(tensor(train(5325,7,4)),1), digit(tensor(train(5325,7,5)),6), none, digit(tensor(train(5325,7,7)),7), none], [digit(tensor(train(5325,8,0)),1), digit(tensor(train(5325,8,1)),9), digit(tensor(train(5325,8,2)),8), none, none, digit(tensor(train(5325,8,5)),3), none, none, digit(tensor(train(5325,8,8)),2)]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 1, X2, X3, 7, X4, X5, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 9, 3, 6, 1, X3, 2, 5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 8, 5, 9, X4, 3, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, 8, X1, X2, X3, X4, 3, 1, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, X4, X5, 4, 2, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[9, 2, 6, 1, X1, X2, 5, X3, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 3, X3, 8, 5, 4, 9, 1]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 5, 2, X1, 1, 6, X2, 7, X3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, 9, 8, X1, X2, 3, X3, X4, 2]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[X1, 1, X2, X3, 7, X4, X5, X6, X7], [X8, X9, 9, 3, 6, 1, X10, 2, 5], [X11, X12, X13, 8, 5, 9, X14, 3, X15], [5, 8, X16, X17, X18, X19, 3, 1, 9], [X20, X21, X22, X23, X24, 4, 2, X25, X26], [9, 2, 6, 1, X27, X28, 5, X29, X30], [X31, X32, 3, X33, 8, 5, 4, 9, 1], [4, 5, 2, X34, 1, 6, X35, 7, X36], [1, 9, 8, X37, X38, 3, X39, X40, 2]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[X1, 1, X2, X3, 7, X4, X5, X6, X7], [X8, X9, 9, 3, 6, 1, X10, 2, 5], [X11, X12, X13, 8, 5, 9, X14, 3, X15], [5, 8, X16, X17, X18, X19, 3, 1, 9], [X20, X21, X22, X23, X24, 4, 2, X25, X26], [9, 2, 6, 1, X27, X28, 5, X29, X30], [X31, X32, 3, X33, 8, 5, 4, 9, 1], [4, 5, 2, X34, 1, 6, X35, 7, X36], [1, 9, 8, X37, X38, 3, X39, X40, 2]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[X1, 1, X2, X3, 7, X4, X5, X6, X7], [X8, X9, 9, 3, 6, 1, X10, 2, 5], [X11, X12, X13, 8, 5, 9, X14, 3, X15], [5, 8, X16, X17, X18, X19, 3, 1, 9], [X20, X21, X22, X23, X24, 4, 2, X25, X26], [9, 2, 6, 1, X27, X28, 5, X29, X30], [X31, X32, 3, X33, 8, 5, 4, 9, 1], [4, 5, 2, X34, 1, 6, X35, 7, X36], [1, 9, 8, X37, X38, 3, X39, X40, 2]]]
# 1 "transpose/2: Called with Ls=~w" [[[X1, 1, X2, X3, 7, X4, X5, X6, X7], [X8, X9, 9, 3, 6, 1, X10, 2, 5], [X11, X12, X13, 8, 5, 9, X14, 3, X15], [5, 8, X16, X17, X18, X19, 3, 1, 9], [X20, X21, X22, X23, X24, 4, 2, X25, X26], [9, 2, 6, 1, X27, X28, 5, X29, X30], [X31, X32, 3, X33, 8, 5, 4, 9, 1], [4, 5, 2, X34, 1, 6, X35, 7, X36], [1, 9, 8, X37, X38, 3, X39, X40, 2]]]
# 1 "transpose/2: Transposed ~w" [[[X1, X2, X3, 5, X4, 9, X5, 4, 1], [1, X6, X7, 8, X8, 2, X9, 5, 9], [X10, 9, X11, X12, X13, 6, 3, 2, 8], [X14, 3, 8, X15, X16, 1, X17, X18, X19], [7, 6, 5, X20, X21, X22, 8, 1, X23], [X24, 1, 9, X25, 4, X26, 5, 6, 3], [X27, X28, X29, 3, 2, 5, 4, X30, X31], [X32, 2, 3, 1, X33, X34, 9, 7, X35], [X36, 5, X37, 9, X38, X39, 1, X40, 2]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[X1, 1, X2, X3, 7, X4, X5, X6, X7], [[X8, X9, 9, 3, 6, 1, X10, 2, 5], [X11, X12, X13, 8, 5, 9, X14, 3, X15], [5, 8, X16, X17, X18, X19, 3, 1, 9], [X20, X21, X22, X23, X24, 4, 2, X25, X26], [9, 2, 6, 1, X27, X28, 5, X29, X30], [X31, X32, 3, X33, 8, 5, 4, 9, 1], [4, 5, 2, X34, 1, 6, X35, 7, X36], [1, 9, 8, X37, X38, 3, X39, X40, 2]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[3, 1, 5, 4, 7, 2, 9, 6, 8]]
# 1 "" [[8, 4, 9, 3, 6, 1, 7, 2, 5]]
# 1 "" [[2, 6, 7, 8, 5, 9, 1, 3, 4]]
# 1 "" [[5, 8, 4, 6, 2, 7, 3, 1, 9]]
# 1 "" [[7, 3, 1, 5, 9, 4, 2, 8, 6]]
# 1 "" [[9, 2, 6, 1, 3, 8, 5, 4, 7]]
# 1 "" [[6, 7, 3, 2, 8, 5, 4, 9, 1]]
# 1 "" [[4, 5, 2, 9, 1, 6, 8, 7, 3]]
# 1 "" [[1, 9, 8, 7, 4, 3, 6, 5, 2]]
# 1 "printing solution" []
# 1 "" [[3, 1, 5, 4, 7, 2, 9, 8, 6]]
# 1 "" [[8, 4, 9, 3, 6, 1, 7, 2, 5]]
# 1 "" [[2, 6, 7, 8, 5, 9, 1, 3, 4]]
# 1 "" [[5, 8, 4, 6, 2, 7, 3, 1, 9]]
# 1 "" [[7, 3, 1, 5, 9, 4, 2, 6, 8]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[digit(tensor(train(6716,0,0)),1), digit(tensor(train(6716,0,1)),7), none, digit(tensor(train(6716,0,3)),9), none, none, none, digit(tensor(train(6716,0,7)),5), none], [none, none, digit(tensor(train(6716,1,2)),5), digit(tensor(train(6716,1,3)),6), digit(tensor(train(6716,1,4)),8), digit(tensor(train(6716,1,5)),7), none, none, digit(tensor(train(6716,1,8)),9)], [digit(tensor(train(6716,2,0)),2), digit(tensor(train(6716,2,1)),6), digit(tensor(train(6716,2,2)),9), digit(tensor(train(6716,2,3)),4), digit(tensor(train(6716,2,4)),1), digit(tensor(train(6716,2,5)),5), none, none, digit(tensor(train(6716,2,8)),8)], [digit(tensor(train(6716,3,0)),6), digit(tensor(train(6716,3,1)),5), none, digit(tensor(train(6716,3,3)),7), digit(tensor(train(6716,3,4)),4), digit(tensor(train(6716,3,5)),8), digit(tensor(train(6716,3,6)),9), digit(tensor(train(6716,3,7)),1), none], [digit(tensor(train(6716,4,0)),8), none, none, none, none, none, digit(tensor(train(6716,4,6)),5), none, none], [none, digit(tensor(train(6716,5,1)),4), digit(tensor(train(6716,5,2)),2), digit(tensor(train(6716,5,3)),5), none, none, none, digit(tensor(train(6716,5,7)),8), none], [none, digit(tensor(train(6716,6,1)),1), none, none, digit(tensor(train(6716,6,4)),6), none, digit(tensor(train(6716,6,6)),7), digit(tensor(train(6716,6,7)),9), digit(tensor(train(6716,6,8)),5)], [none, digit(tensor(train(6716,7,1)),8), none, digit(tensor(train(6716,7,3)),3), none, digit(tensor(train(6716,7,5)),4), none, none, none], [none, none, digit(tensor(train(6716,8,2)),6), digit(tensor(train(6716,8,3)),1), digit(tensor(train(6716,8,4)),7), none, digit(tensor(train(6716,8,6)),8), none, none]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, 7, X1, 9, X2, X3, X4, 5, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 5, 6, 8, 7, X3, X4, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[2, 6, 9, 4, 1, 5, X1, X2, 8]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[6, 5, X1, 7, 4, 8, 9, 1, X2]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, X1, X2, X3, X4, X5, 5, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 4, 2, 5, X2, X3, X4, 8, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 1, X2, X3, 6, X4, 7, 9, 5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, X2, 3, X3, 4, X4, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 6, 1, 7, X3, 8, X4, X5]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[1, 7, X1, 9, X2, X3, X4, 5, X5], [X6, X7, 5, 6, 8, 7, X8, X9, 9], [2, 6, 9, 4, 1, 5, X10, X11, 8], [6, 5, X12, 7, 4, 8, 9, 1, X13], [8, X14, X15, X16, X17, X18, 5, X19, X20], [X21, 4, 2, 5, X22, X23, X24, 8, X25], [X26, 1, X27, X28, 6, X29, 7, 9, 5], [X30, 8, X31, 3, X32, 4, X33, X34, X35], [X36, X37, 6, 1, 7, X38, 8, X39, X40]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[1, 7, X1, 9, X2, X3, X4, 5, X5], [X6, X7, 5, 6, 8, 7, X8, X9, 9], [2, 6, 9, 4, 1, 5, X10, X11, 8], [6, 5, X12, 7, 4, 8, 9, 1, X13], [8, X14, X15, X16, X17, X18, 5, X19, X20], [X21, 4, 2, 5, X22, X23, X24, 8, X25], [X26, 1, X27, X28, 6, X29, 7, 9, 5], [X30, 8, X31, 3, X32, 4, X33, X34, X35], [X36, X37, 6, 1, 7, X38, 8, X39, X40]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[1, 7, X1, 9, X2, X3, X4, 5, X5], [X6, X7, 5, 6, 8, 7, X8, X9, 9], [2, 6, 9, 4, 1, 5, X10, X11, 8], [6, 5, X12, 7, 4, 8, 9, 1, X13], [8, X14, X15, X16, X17, X18, 5, X19, X20], [X21, 4, 2, 5, X22, X23, X24, 8, X25], [X26, 1, X27, X28, 6, X29, 7, 9, 5], [X30, 8, X31, 3, X32, 4, X33, X34, X35], [X36, X37, 6, 1, 7, X38, 8, X39, X40]]]
# 1 "transpose/2: Called with Ls=~w" [[[1, 7, X1, 9, X2, X3, X4, 5, X5], [X6, X7, 5, 6, 8, 7, X8, X9, 9], [2, 6, 9, 4, 1, 5, X10, X11, 8], [6, 5, X12, 7, 4, 8, 9, 1, X13], [8, X14, X15, X16, X17, X18, 5, X19, X20], [X21, 4, 2, 5, X22, X23, X24, 8, X25], [X26, 1, X27, X28, 6, X29, 7, 9, 5], [X30, 8, X31, 3, X32, 4, X33, X34, X35], [X36, X37, 6, 1, 7, X38, 8, X39, X40]]]
# Iteration:  3 	s:87.5221 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[1, X1, 2, 6, 8, X2, X3, X4, X5], [7, X6, 6, 5, X7, 4, 1, 8, X8], [X9, 5, 9, X10, X11, 2, X12, X13, 6], [9, 6, 4, 7, X14, 5, X15, 3, 1], [X16, 8, 1, 4, X17, X18, 6, X19, 7], [X20, 7, 5, 8, X21, X22, X23, 4, X24], [X25, X26, X27, 9, 5, X28, 7, X29, 8], [5, X30, X31, 1, X32, 8, 9, X33, X34], [X35, 9, 8, X36, X37, X38, 5, X39, X40]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[1, 7, X1, 9, X2, X3, X4, 5, X5], [[X6, X7, 5, 6, 8, 7, X8, X9, 9], [2, 6, 9, 4, 1, 5, X10, X11, 8], [6, 5, X12, 7, 4, 8, 9, 1, X13], [8, X14, X15, X16, X17, X18, 5, X19, X20], [X21, 4, 2, 5, X22, X23, X24, 8, X25], [X26, 1, X27, X28, 6, X29, 7, 9, 5], [X30, 8, X31, 3, X32, 4, X33, X34, X35], [X36, X37, 6, 1, 7, X38, 8, X39, X40]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[1, 7, 8, 9, 2, 3, 4, 5, 6]]
# 1 "" [[4, 3, 5, 6, 8, 7, 1, 2, 9]]
# 1 "" [[2, 6, 9, 4, 1, 5, 3, 7, 8]]
# 1 "" [[6, 5, 3, 7, 4, 8, 9, 1, 2]]
# 1 "" [[8, 9, 1, 2, 3, 6, 5, 4, 7]]
# 1 "" [[7, 4, 2, 5, 9, 1, 6, 8, 3]]
# 1 "" [[3, 1, 4, 8, 6, 2, 7, 9, 5]]
# 1 "" [[9, 8, 7, 3, 5, 4, 2, 6, 1]]
# 1 "" [[5, 2, 6, 1, 7, 9, 8, 3, 4]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[none, none, none, digit(tensor(train(1553,0,3)),6), none, none, digit(tensor(train(1553,0,6)),2), none, digit(tensor(train(1553,0,8)),9)], [digit(tensor(train(1553,1,0)),4), digit(tensor(train(1553,1,1)),6), none, digit(tensor(train(1553,1,3)),5), digit(tensor(train(1553,1,4)),1), none, digit(tensor(train(1553,1,6)),3), none, none], [digit(tensor(train(1553,2,0)),2), digit(tensor(train(1553,2,1)),3), none, none, digit(tensor(train(1553,2,4)),8), digit(tensor(train(1553,2,5)),9), none, none, digit(tensor(train(1553,2,8)),6)], [none, digit(tensor(train(1553,3,1)),7), digit(tensor(train(1553,3,2)),1), none, digit(tensor(train(1553,3,4)),5), digit(tensor(train(1553,3,5)),4), none, digit(tensor(train(1553,3,7)),2), none], [digit(tensor(train(1553,4,0)),8), digit(tensor(train(1553,4,1)),9), none, digit(tensor(train(1553,4,3)),2), digit(tensor(train(1553,4,4)),6), digit(tensor(train(1553,4,5)),1), none, none, digit(tensor(train(1553,4,8)),5)], [none, digit(tensor(train(1553,5,1)),2), digit(tensor(train(1553,5,2)),5), none, none, digit(tensor(train(1553,5,5)),7), digit(tensor(train(1553,5,6)),4), none, none], [none, none, none, digit(tensor(train(1553,6,3)),7), digit(tensor(train(1553,6,4)),4), digit(tensor(train(1553,6,5)),6), digit(tensor(train(1553,6,6)),8), digit(tensor(train(1553,6,7)),1), digit(tensor(train(1553,6,8)),3)], [none, digit(tensor(train(1553,7,1)),8), none, none, none, none, digit(tensor(train(1553,7,6)),9), none, none], [none, none, digit(tensor(train(1553,8,2)),6), digit(tensor(train(1553,8,3)),3), digit(tensor(train(1553,8,4)),9), none, digit(tensor(train(1553,8,6)),5), digit(tensor(train(1553,8,7)),7), none]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 6, X4, X5, 2, X6, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 6, X1, 5, 1, X2, 3, X3, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[2, 3, X1, X2, 8, 9, X3, X4, 6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 7, 1, X2, 5, 4, X3, 2, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, 9, X1, 2, 6, 1, X2, X3, 5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 2, 5, X2, X3, 7, 4, X4, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 7, 4, 6, 8, 1, 3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, X2, X3, X4, X5, 9, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 6, 3, 9, X3, 5, 7, X4]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[X1, X2, X3, 6, X4, X5, 2, X6, 9], [4, 6, X7, 5, 1, X8, 3, X9, X10], [2, 3, X11, X12, 8, 9, X13, X14, 6], [X15, 7, 1, X16, 5, 4, X17, 2, X18], [8, 9, X19, 2, 6, 1, X20, X21, 5], [X22, 2, 5, X23, X24, 7, 4, X25, X26], [X27, X28, X29, 7, 4, 6, 8, 1, 3], [X30, 8, X31, X32, X33, X34, 9, X35, X36], [X37, X38, 6, 3, 9, X39, 5, 7, X40]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[X1, X2, X3, 6, X4, X5, 2, X6, 9], [4, 6, X7, 5, 1, X8, 3, X9, X10], [2, 3, X11, X12, 8, 9, X13, X14, 6], [X15, 7, 1, X16, 5, 4, X17, 2, X18], [8, 9, X19, 2, 6, 1, X20, X21, 5], [X22, 2, 5, X23, X24, 7, 4, X25, X26], [X27, X28, X29, 7, 4, 6, 8, 1, 3], [X30, 8, X31, X32, X33, X34, 9, X35, X36], [X37, X38, 6, 3, 9, X39, 5, 7, X40]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[X1, X2, X3, 6, X4, X5, 2, X6, 9], [4, 6, X7, 5, 1, X8, 3, X9, X10], [2, 3, X11, X12, 8, 9, X13, X14, 6], [X15, 7, 1, X16, 5, 4, X17, 2, X18], [8, 9, X19, 2, 6, 1, X20, X21, 5], [X22, 2, 5, X23, X24, 7, 4, X25, X26], [X27, X28, X29, 7, 4, 6, 8, 1, 3], [X30, 8, X31, X32, X33, X34, 9, X35, X36], [X37, X38, 6, 3, 9, X39, 5, 7, X40]]]
# 1 "transpose/2: Called with Ls=~w" [[[X1, X2, X3, 6, X4, X5, 2, X6, 9], [4, 6, X7, 5, 1, X8, 3, X9, X10], [2, 3, X11, X12, 8, 9, X13, X14, 6], [X15, 7, 1, X16, 5, 4, X17, 2, X18], [8, 9, X19, 2, 6, 1, X20, X21, 5], [X22, 2, 5, X23, X24, 7, 4, X25, X26], [X27, X28, X29, 7, 4, 6, 8, 1, 3], [X30, 8, X31, X32, X33, X34, 9, X35, X36], [X37, X38, 6, 3, 9, X39, 5, 7, X40]]]
# Iteration:  4 	s:103.9672 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[X1, 4, 2, X2, 8, X3, X4, X5, X6], [X7, 6, 3, 7, 9, 2, X8, 8, X9], [X10, X11, X12, 1, X13, 5, X14, X15, 6], [6, 5, X16, X17, 2, X18, 7, X19, 3], [X20, 1, 8, 5, 6, X21, 4, X22, 9], [X23, X24, 9, 4, 1, 7, 6, X25, X26], [2, 3, X27, X28, X29, 4, 8, 9, 5], [X30, X31, X32, 2, X33, X34, 1, X35, 7], [9, X36, 6, X37, 5, X38, 3, X39, X40]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[X1, X2, X3, 6, X4, X5, 2, X6, 9], [[4, 6, X7, 5, 1, X8, 3, X9, X10], [2, 3, X11, X12, 8, 9, X13, X14, 6], [X15, 7, 1, X16, 5, 4, X17, 2, X18], [8, 9, X19, 2, 6, 1, X20, X21, 5], [X22, 2, 5, X23, X24, 7, 4, X25, X26], [X27, X28, X29, 7, 4, 6, 8, 1, 3], [X30, 8, X31, X32, X33, X34, 9, X35, X36], [X37, X38, 6, 3, 9, X39, 5, 7, X40]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[5, 1, 8, 6, 7, 3, 2, 4, 9]]
# 1 "" [[4, 6, 9, 5, 1, 2, 3, 8, 7]]
# 1 "" [[2, 3, 7, 4, 8, 9, 1, 5, 6]]
# 1 "" [[3, 7, 1, 9, 5, 4, 6, 2, 8]]
# 1 "" [[8, 9, 4, 2, 6, 1, 7, 3, 5]]
# 1 "" [[6, 2, 5, 8, 3, 7, 4, 9, 1]]
# 1 "" [[9, 5, 2, 7, 4, 6, 8, 1, 3]]
# 1 "" [[7, 8, 3, 1, 2, 5, 9, 6, 4]]
# 1 "" [[1, 4, 6, 3, 9, 8, 5, 7, 2]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[digit(tensor(train(1371,0,0)),2), digit(tensor(train(1371,0,1)),4), digit(tensor(train(1371,0,2)),5), none, digit(tensor(train(1371,0,4)),9), digit(tensor(train(1371,0,5)),1), none, digit(tensor(train(1371,0,7)),8), digit(tensor(train(1371,0,8)),6)], [none, none, none, none, digit(tensor(train(1371,1,4)),4), none, none, digit(tensor(train(1371,1,7)),9), digit(tensor(train(1371,1,8)),1)], [none, digit(tensor(train(1371,2,1)),8), none, none, digit(tensor(train(1371,2,4)),3), digit(tensor(train(1371,2,5)),5), none, digit(tensor(train(1371,2,7)),4), none], [digit(tensor(train(1371,3,0)),9), none, none, none, none, none, none, none, digit(tensor(train(1371,3,8)),5)], [none, none, none, digit(tensor(train(1371,4,3)),1), digit(tensor(train(1371,4,4)),7), none, none, none, digit(tensor(train(1371,4,8)),9)], [digit(tensor(train(1371,5,0)),7), none, digit(tensor(train(1371,5,2)),8), digit(tensor(train(1371,5,3)),3), digit(tensor(train(1371,5,4)),5), digit(tensor(train(1371,5,5)),9), none, none, digit(tensor(train(1371,5,8)),2)], [none, digit(tensor(train(1371,6,1)),2), none, none, none, digit(tensor(train(1371,6,5)),7), digit(tensor(train(1371,6,6)),9), digit(tensor(train(1371,6,7)),1), none], [digit(tensor(train(1371,7,0)),8), digit(tensor(train(1371,7,1)),9), none, none, none, none, digit(tensor(train(1371,7,6)),6), digit(tensor(train(1371,7,7)),5), digit(tensor(train(1371,7,8)),3)], [digit(tensor(train(1371,8,0)),4), digit(tensor(train(1371,8,1)),5), digit(tensor(train(1371,8,2)),1), none, digit(tensor(train(1371,8,4)),6), digit(tensor(train(1371,8,5)),3), digit(tensor(train(1371,8,6)),7), none, digit(tensor(train(1371,8,8)),8)]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[2, 4, 5, X1, 9, 1, X2, 8, 6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, X4, 4, X5, X6, 9, 1]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, X2, X3, 3, 5, X4, 4, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[9, X1, X2, X3, X4, X5, X6, X7, 5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 1, 7, X4, X5, X6, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[7, X1, 8, 3, 5, 9, X2, X3, 2]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 2, X2, X3, X4, 7, 9, 1, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, 9, X1, X2, X3, X4, 6, 5, 3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 5, 1, X1, 6, 3, 7, X2, 8]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[2, 4, 5, X1, 9, 1, X2, 8, 6], [X3, X4, X5, X6, 4, X7, X8, 9, 1], [X9, 8, X10, X11, 3, 5, X12, 4, X13], [9, X14, X15, X16, X17, X18, X19, X20, 5], [X21, X22, X23, 1, 7, X24, X25, X26, 9], [7, X27, 8, 3, 5, 9, X28, X29, 2], [X30, 2, X31, X32, X33, 7, 9, 1, X34], [8, 9, X35, X36, X37, X38, 6, 5, 3], [4, 5, 1, X39, 6, 3, 7, X40, 8]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[2, 4, 5, X1, 9, 1, X2, 8, 6], [X3, X4, X5, X6, 4, X7, X8, 9, 1], [X9, 8, X10, X11, 3, 5, X12, 4, X13], [9, X14, X15, X16, X17, X18, X19, X20, 5], [X21, X22, X23, 1, 7, X24, X25, X26, 9], [7, X27, 8, 3, 5, 9, X28, X29, 2], [X30, 2, X31, X32, X33, 7, 9, 1, X34], [8, 9, X35, X36, X37, X38, 6, 5, 3], [4, 5, 1, X39, 6, 3, 7, X40, 8]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[2, 4, 5, X1, 9, 1, X2, 8, 6], [X3, X4, X5, X6, 4, X7, X8, 9, 1], [X9, 8, X10, X11, 3, 5, X12, 4, X13], [9, X14, X15, X16, X17, X18, X19, X20, 5], [X21, X22, X23, 1, 7, X24, X25, X26, 9], [7, X27, 8, 3, 5, 9, X28, X29, 2], [X30, 2, X31, X32, X33, 7, 9, 1, X34], [8, 9, X35, X36, X37, X38, 6, 5, 3], [4, 5, 1, X39, 6, 3, 7, X40, 8]]]
# 1 "transpose/2: Called with Ls=~w" [[[2, 4, 5, X1, 9, 1, X2, 8, 6], [X3, X4, X5, X6, 4, X7, X8, 9, 1], [X9, 8, X10, X11, 3, 5, X12, 4, X13], [9, X14, X15, X16, X17, X18, X19, X20, 5], [X21, X22, X23, 1, 7, X24, X25, X26, 9], [7, X27, 8, 3, 5, 9, X28, X29, 2], [X30, 2, X31, X32, X33, 7, 9, 1, X34], [8, 9, X35, X36, X37, X38, 6, 5, 3], [4, 5, 1, X39, 6, 3, 7, X40, 8]]]
# Iteration:  5 	s:60.5832 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[2, X1, X2, 9, X3, 7, X4, 8, 4], [4, X5, 8, X6, X7, X8, 2, 9, 5], [5, X9, X10, X11, X12, 8, X13, X14, 1], [X15, X16, X17, X18, 1, 3, X19, X20, X21], [9, 4, 3, X22, 7, 5, X23, X24, 6], [1, X25, 5, X26, X27, 9, 7, X28, 3], [X29, X30, X31, X32, X33, X34, 9, 6, 7], [8, 9, 4, X35, X36, X37, 1, 5, X38], [6, 1, X39, 5, 9, 2, X40, 3, 8]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[2, 4, 5, X1, 9, 1, X2, 8, 6], [[X3, X4, X5, X6, 4, X7, X8, 9, 1], [X9, 8, X10, X11, 3, 5, X12, 4, X13], [9, X14, X15, X16, X17, X18, X19, X20, 5], [X21, X22, X23, 1, 7, X24, X25, X26, 9], [7, X27, 8, 3, 5, 9, X28, X29, 2], [X30, 2, X31, X32, X33, 7, 9, 1, X34], [8, 9, X35, X36, X37, X38, 6, 5, 3], [4, 5, 1, X39, 6, 3, 7, X40, 8]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[2, 4, 5, 7, 9, 1, 3, 8, 6]]
# 1 "" [[3, 7, 6, 2, 4, 8, 5, 9, 1]]
# 1 "" [[1, 8, 9, 6, 3, 5, 2, 4, 7]]
# 1 "" [[9, 3, 4, 8, 2, 6, 1, 7, 5]]
# 1 "" [[5, 6, 2, 1, 7, 4, 8, 3, 9]]
# 1 "" [[7, 1, 8, 3, 5, 9, 4, 6, 2]]
# 1 "" [[6, 2, 3, 5, 8, 7, 9, 1, 4]]
# 1 "" [[8, 9, 7, 4, 1, 2, 6, 5, 3]]
# 1 "" [[4, 5, 1, 9, 6, 3, 7, 2, 8]]
# 1 "printing solution" []
# 1 "" [[2, 4, 5, 7, 9, 1, 3, 8, 6]]
# 1 "" [[6, 7, 3, 2, 4, 8, 5, 9, 1]]
# 1 "" [[1, 8, 9, 6, 3, 5, 2, 4, 7]]
# 1 "" [[9, 3, 4, 8, 2, 6, 1, 7, 5]]
# 1 "" [[5, 6, 2, 1, 7, 4, 8, 3, 9]]
# 1 "" [[7, 1, 8, 3, 5, 9, 4, 6, 2]]
# 1 "" [[3, 2, 6, 5, 8, 7, 9, 1, 4]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[digit(tensor(train(1269,0,0)),6), none, none, digit(tensor(train(1269,0,3)),8), none, digit(tensor(train(1269,0,5)),9), digit(tensor(train(1269,0,6)),7), digit(tensor(train(1269,0,7)),2), none], [digit(tensor(train(1269,1,0)),2), digit(tensor(train(1269,1,1)),3), digit(tensor(train(1269,1,2)),8), none, none, none, none, digit(tensor(train(1269,1,7)),6), none], [digit(tensor(train(1269,2,0)),9), digit(tensor(train(1269,2,1)),7), none, digit(tensor(train(1269,2,3)),3), none, digit(tensor(train(1269,2,5)),2), none, none, digit(tensor(train(1269,2,8)),5)], [digit(tensor(train(1269,3,0)),1), none, digit(tensor(train(1269,3,2)),2), none, none, digit(tensor(train(1269,3,5)),3), digit(tensor(train(1269,3,6)),9), none, none], [none, digit(tensor(train(1269,4,1)),6), digit(tensor(train(1269,4,2)),3), digit(tensor(train(1269,4,3)),5), none, digit(tensor(train(1269,4,5)),1), none, digit(tensor(train(1269,4,7)),4), none], [digit(tensor(train(1269,5,0)),8), digit(tensor(train(1269,5,1)),5), none, none, digit(tensor(train(1269,5,4)),2), digit(tensor(train(1269,5,5)),7), none, none, none], [none, none, none, none, digit(tensor(train(1269,6,4)),5), none, digit(tensor(train(1269,6,6)),2), digit(tensor(train(1269,6,7)),7), none], [none, digit(tensor(train(1269,7,1)),9), none, none, digit(tensor(train(1269,7,4)),7), none, digit(tensor(train(1269,7,6)),5), none, none], [digit(tensor(train(1269,8,0)),5), digit(tensor(train(1269,8,1)),2), none, digit(tensor(train(1269,8,3)),1), digit(tensor(train(1269,8,4)),3), digit(tensor(train(1269,8,5)),8), digit(tensor(train(1269,8,6)),6), digit(tensor(train(1269,8,7)),9), digit(tensor(train(1269,8,8)),4)]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[6, X1, X2, 8, X3, 9, 7, 2, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[2, 3, 8, X1, X2, X3, X4, 6, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[9, 7, X1, 3, X2, 2, X3, X4, 5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, X1, 2, X2, X3, 3, 9, X4, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 6, 3, 5, X2, 1, X3, 4, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, 5, X1, X2, 2, 7, X3, X4, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, X4, 5, X5, 2, 7, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 9, X2, X3, 7, X4, 5, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, 2, X1, 1, 3, 8, 6, 9, 4]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[6, X1, X2, 8, X3, 9, 7, 2, X4], [2, 3, 8, X5, X6, X7, X8, 6, X9], [9, 7, X10, 3, X11, 2, X12, X13, 5], [1, X14, 2, X15, X16, 3, 9, X17, X18], [X19, 6, 3, 5, X20, 1, X21, 4, X22], [8, 5, X23, X24, 2, 7, X25, X26, X27], [X28, X29, X30, X31, 5, X32, 2, 7, X33], [X34, 9, X35, X36, 7, X37, 5, X38, X39], [5, 2, X40, 1, 3, 8, 6, 9, 4]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[6, X1, X2, 8, X3, 9, 7, 2, X4], [2, 3, 8, X5, X6, X7, X8, 6, X9], [9, 7, X10, 3, X11, 2, X12, X13, 5], [1, X14, 2, X15, X16, 3, 9, X17, X18], [X19, 6, 3, 5, X20, 1, X21, 4, X22], [8, 5, X23, X24, 2, 7, X25, X26, X27], [X28, X29, X30, X31, 5, X32, 2, 7, X33], [X34, 9, X35, X36, 7, X37, 5, X38, X39], [5, 2, X40, 1, 3, 8, 6, 9, 4]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[6, X1, X2, 8, X3, 9, 7, 2, X4], [2, 3, 8, X5, X6, X7, X8, 6, X9], [9, 7, X10, 3, X11, 2, X12, X13, 5], [1, X14, 2, X15, X16, 3, 9, X17, X18], [X19, 6, 3, 5, X20, 1, X21, 4, X22], [8, 5, X23, X24, 2, 7, X25, X26, X27], [X28, X29, X30, X31, 5, X32, 2, 7, X33], [X34, 9, X35, X36, 7, X37, 5, X38, X39], [5, 2, X40, 1, 3, 8, 6, 9, 4]]]
# 1 "transpose/2: Called with Ls=~w" [[[6, X1, X2, 8, X3, 9, 7, 2, X4], [2, 3, 8, X5, X6, X7, X8, 6, X9], [9, 7, X10, 3, X11, 2, X12, X13, 5], [1, X14, 2, X15, X16, 3, 9, X17, X18], [X19, 6, 3, 5, X20, 1, X21, 4, X22], [8, 5, X23, X24, 2, 7, X25, X26, X27], [X28, X29, X30, X31, 5, X32, 2, 7, X33], [X34, 9, X35, X36, 7, X37, 5, X38, X39], [5, 2, X40, 1, 3, 8, 6, 9, 4]]]
# Iteration:  6 	s:1565.0069 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[6, 2, 9, 1, X1, 8, X2, X3, 5], [X4, 3, 7, X5, 6, 5, X6, 9, 2], [X7, 8, X8, 2, 3, X9, X10, X11, X12], [8, X13, 3, X14, 5, X15, X16, X17, 1], [X18, X19, X20, X21, X22, 2, 5, 7, 3], [9, X23, 2, 3, 1, 7, X24, X25, 8], [7, X26, X27, 9, X28, X29, 2, 5, 6], [2, 6, X30, X31, 4, X32, 7, X33, 9], [X34, X35, 5, X36, X37, X38, X39, X40, 4]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[6, X1, X2, 8, X3, 9, 7, 2, X4], [[2, 3, 8, X5, X6, X7, X8, 6, X9], [9, 7, X10, 3, X11, 2, X12, X13, 5], [1, X14, 2, X15, X16, 3, 9, X17, X18], [X19, 6, 3, 5, X20, 1, X21, 4, X22], [8, 5, X23, X24, 2, 7, X25, X26, X27], [X28, X29, X30, X31, 5, X32, 2, 7, X33], [X34, 9, X35, X36, 7, X37, 5, X38, X39], [5, 2, X40, 1, 3, 8, 6, 9, 4]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[6, 1, 5, 8, 4, 9, 7, 2, 3]]
# 1 "" [[2, 3, 8, 7, 1, 5, 4, 6, 9]]
# 1 "" [[9, 7, 4, 3, 6, 2, 1, 8, 5]]
# 1 "" [[1, 4, 2, 6, 8, 3, 9, 5, 7]]
# 1 "" [[7, 6, 3, 5, 9, 1, 8, 4, 2]]
# 1 "" [[8, 5, 9, 4, 2, 7, 3, 1, 6]]
# 1 "" [[3, 8, 6, 9, 5, 4, 2, 7, 1]]
# 1 "" [[4, 9, 1, 2, 7, 6, 5, 3, 8]]
# 1 "" [[5, 2, 7, 1, 3, 8, 6, 9, 4]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[digit(tensor(train(4322,0,0)),6), digit(tensor(train(4322,0,1)),3), digit(tensor(train(4322,0,2)),2), none, digit(tensor(train(4322,0,4)),9), none, none, none, digit(tensor(train(4322,0,8)),4)], [digit(tensor(train(4322,1,0)),1), digit(tensor(train(4322,1,1)),5), none, digit(tensor(train(4322,1,3)),8), digit(tensor(train(4322,1,4)),3), digit(tensor(train(4322,1,5)),4), digit(tensor(train(4322,1,6)),2), digit(tensor(train(4322,1,7)),7), digit(tensor(train(4322,1,8)),6)], [digit(tensor(train(4322,2,0)),4), digit(tensor(train(4322,2,1)),7), none, none, none, none, digit(tensor(train(4322,2,6)),9), digit(tensor(train(4322,2,7)),3), none], [digit(tensor(train(4322,3,0)),8), none, none, none, none, digit(tensor(train(4322,3,5)),1), digit(tensor(train(4322,3,6)),4), none, digit(tensor(train(4322,3,8)),7)], [none, none, digit(tensor(train(4322,4,2)),7), none, digit(tensor(train(4322,4,4)),5), digit(tensor(train(4322,4,5)),8), none, none, digit(tensor(train(4322,4,8)),1)], [digit(tensor(train(4322,5,0)),5), digit(tensor(train(4322,5,1)),1), none, digit(tensor(train(4322,5,3)),4), none, none, none, digit(tensor(train(4322,5,7)),2), none], [none, digit(tensor(train(4322,6,1)),6), none, none, digit(tensor(train(4322,6,4)),8), none, none, none, digit(tensor(train(4322,6,8)),9)], [none, digit(tensor(train(4322,7,1)),2), digit(tensor(train(4322,7,2)),4), none, digit(tensor(train(4322,7,4)),1), none, digit(tensor(train(4322,7,6)),8), digit(tensor(train(4322,7,7)),6), digit(tensor(train(4322,7,8)),3)], [none, digit(tensor(train(4322,8,1)),8), none, none, digit(tensor(train(4322,8,4)),4), none, none, none, digit(tensor(train(4322,8,8)),2)]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[6, 3, 2, X1, 9, X2, X3, X4, 4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, 5, X1, 8, 3, 4, 2, 7, 6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 7, X1, X2, X3, X4, 9, 3, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, X1, X2, X3, X4, 1, 4, X5, 7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 7, X3, 5, 8, X4, X5, 1]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, 1, X1, 4, X2, X3, X4, 2, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 6, X2, X3, 8, X4, X5, X6, 9]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 2, 4, X2, 1, X3, 8, 6, 3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, X2, X3, 4, X4, X5, X6, 2]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[6, 3, 2, X1, 9, X2, X3, X4, 4], [1, 5, X5, 8, 3, 4, 2, 7, 6], [4, 7, X6, X7, X8, X9, 9, 3, X10], [8, X11, X12, X13, X14, 1, 4, X15, 7], [X16, X17, 7, X18, 5, 8, X19, X20, 1], [5, 1, X21, 4, X22, X23, X24, 2, X25], [X26, 6, X27, X28, 8, X29, X30, X31, 9], [X32, 2, 4, X33, 1, X34, 8, 6, 3], [X35, 8, X36, X37, 4, X38, X39, X40, 2]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[6, 3, 2, X1, 9, X2, X3, X4, 4], [1, 5, X5, 8, 3, 4, 2, 7, 6], [4, 7, X6, X7, X8, X9, 9, 3, X10], [8, X11, X12, X13, X14, 1, 4, X15, 7], [X16, X17, 7, X18, 5, 8, X19, X20, 1], [5, 1, X21, 4, X22, X23, X24, 2, X25], [X26, 6, X27, X28, 8, X29, X30, X31, 9], [X32, 2, 4, X33, 1, X34, 8, 6, 3], [X35, 8, X36, X37, 4, X38, X39, X40, 2]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[6, 3, 2, X1, 9, X2, X3, X4, 4], [1, 5, X5, 8, 3, 4, 2, 7, 6], [4, 7, X6, X7, X8, X9, 9, 3, X10], [8, X11, X12, X13, X14, 1, 4, X15, 7], [X16, X17, 7, X18, 5, 8, X19, X20, 1], [5, 1, X21, 4, X22, X23, X24, 2, X25], [X26, 6, X27, X28, 8, X29, X30, X31, 9], [X32, 2, 4, X33, 1, X34, 8, 6, 3], [X35, 8, X36, X37, 4, X38, X39, X40, 2]]]
# 1 "transpose/2: Called with Ls=~w" [[[6, 3, 2, X1, 9, X2, X3, X4, 4], [1, 5, X5, 8, 3, 4, 2, 7, 6], [4, 7, X6, X7, X8, X9, 9, 3, X10], [8, X11, X12, X13, X14, 1, 4, X15, 7], [X16, X17, 7, X18, 5, 8, X19, X20, 1], [5, 1, X21, 4, X22, X23, X24, 2, X25], [X26, 6, X27, X28, 8, X29, X30, X31, 9], [X32, 2, 4, X33, 1, X34, 8, 6, 3], [X35, 8, X36, X37, 4, X38, X39, X40, 2]]]
# Iteration:  7 	s:29.8121 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[6, 1, 4, 8, X1, 5, X2, X3, X4], [3, 5, 7, X5, X6, 1, 6, 2, 8], [2, X7, X8, X9, 7, X10, X11, 4, X12], [X13, 8, X14, X15, X16, 4, X17, X18, X19], [9, 3, X20, X21, 5, X22, 8, 1, 4], [X23, 4, X24, 1, 8, X25, X26, X27, X28], [X29, 2, 9, 4, X30, X31, X32, 8, X33], [X34, 7, 3, X35, X36, 2, X37, 6, X38], [4, 6, X39, 7, 1, X40, 9, 3, 2]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[6, 3, 2, X1, 9, X2, X3, X4, 4], [[1, 5, X5, 8, 3, 4, 2, 7, 6], [4, 7, X6, X7, X8, X9, 9, 3, X10], [8, X11, X12, X13, X14, 1, 4, X15, 7], [X16, X17, 7, X18, 5, 8, X19, X20, 1], [5, 1, X21, 4, X22, X23, X24, 2, X25], [X26, 6, X27, X28, 8, X29, X30, X31, 9], [X32, 2, 4, X33, 1, X34, 8, 6, 3], [X35, 8, X36, X37, 4, X38, X39, X40, 2]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[6, 3, 2, 5, 9, 7, 1, 8, 4]]
# 1 "" [[1, 5, 9, 8, 3, 4, 2, 7, 6]]
# 1 "" [[4, 7, 8, 1, 2, 6, 9, 3, 5]]
# 1 "" [[8, 9, 3, 2, 6, 1, 4, 5, 7]]
# 1 "" [[2, 4, 7, 3, 5, 8, 6, 9, 1]]
# 1 "" [[5, 1, 6, 4, 7, 9, 3, 2, 8]]
# 1 "" [[3, 6, 1, 7, 8, 2, 5, 4, 9]]
# 1 "" [[7, 2, 4, 9, 1, 5, 8, 6, 3]]
# 1 "" [[9, 8, 5, 6, 4, 3, 7, 1, 2]]
# 1 "printing solution" []
# 1 "" [[6, 3, 2, 5, 9, 7, 1, 8, 4]]
# 1 "" [[1, 5, 9, 8, 3, 4, 2, 7, 6]]
# 1 "" [[4, 7, 8, 1, 6, 2, 9, 3, 5]]
# 1 "" [[8, 9, 3, 6, 2, 1, 4, 5, 7]]
# 1 "" [[2, 4, 7, 3, 5, 8, 6, 9, 1]]
# 1 "" [[5, 1, 6, 4, 7, 9, 3, 2, 8]]
# 1 "" [[7, 6, 1, 2, 8, 3, 5, 4, 9]]
# 1 "" [[9, 2, 4, 7, 1, 5, 8, 6, 3]]
# 1 "" [[3, 8, 5, 9, 4, 6, 7, 1, 2]]
# 1 "printing solution" []
# 1 "" [[6, 3, 2, 5, 9, 7, 1, 8, 4]]
# 1 "" [[1, 5, 9, 8, 3, 4, 2, 7, 6]]
# 1 "" [[4, 7, 8, 1, 6, 2, 9, 3, 5]]
# 1 "" [[8, 9, 6, 3, 2, 1, 4, 5, 7]]
# 1 "" [[2, 4, 7, 6, 5, 8, 3, 9, 1]]
# 1 "" [[5, 1, 3, 4, 7, 9, 6, 2, 8]]
# 1 "printing solution" []
# 1 "" [[6, 3, 2, 7, 9, 5, 1, 8, 4]]
# 1 "" [[1, 5, 9, 8, 3, 4, 2, 7, 6]]
# 1 "" [[4, 7, 8, 1, 6, 2, 9, 3, 5]]
# 1 "" [[8, 9, 3, 6, 2, 1, 4, 5, 7]]
# 1 "" [[2, 4, 7, 3, 5, 8, 6, 9, 1]]
# 1 "" [[5, 1, 6, 4, 7, 9, 3, 2, 8]]
# 1 "" [[7, 6, 1, 2, 8, 3, 5, 4, 9]]
# 1 "" [[9, 2, 4, 5, 1, 7, 8, 6, 3]]
# 1 "printing solution" []
# 1 "" [[6, 3, 2, 7, 9, 5, 1, 8, 4]]
# 1 "" [[1, 5, 9, 8, 3, 4, 2, 7, 6]]
# 1 "" [[4, 7, 8, 1, 6, 2, 9, 3, 5]]
# 1 "" [[8, 9, 6, 3, 2, 1, 4, 5, 7]]
# 1 "" [[2, 4, 7, 6, 5, 8, 3, 9, 1]]
# 1 "" [[5, 1, 3, 4, 7, 9, 6, 2, 8]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[digit(tensor(train(3318,0,0)),5), digit(tensor(train(3318,0,1)),9), none, none, digit(tensor(train(3318,0,4)),3), none, digit(tensor(train(3318,0,6)),7), digit(tensor(train(3318,0,7)),6), digit(tensor(train(3318,0,8)),2)], [none, none, digit(tensor(train(3318,1,2)),8), digit(tensor(train(3318,1,3)),7), digit(tensor(train(3318,1,4)),5), digit(tensor(train(3318,1,5)),9), none, digit(tensor(train(3318,1,7)),4), digit(tensor(train(3318,1,8)),1)], [none, none, none, digit(tensor(train(3318,2,3)),2), digit(tensor(train(3318,2,4)),6), digit(tensor(train(3318,2,5)),4), none, none, none], [none, digit(tensor(train(3318,3,1)),4), digit(tensor(train(3318,3,2)),3), none, none, digit(tensor(train(3318,3,5)),1), none, none, none], [digit(tensor(train(3318,4,0)),8), none, digit(tensor(train(3318,4,2)),2), none, digit(tensor(train(3318,4,4)),7), none, digit(tensor(train(3318,4,6)),1), digit(tensor(train(3318,4,7)),9), none], [digit(tensor(train(3318,5,0)),1), digit(tensor(train(3318,5,1)),7), none, none, none, digit(tensor(train(3318,5,5)),5), none, none, none], [digit(tensor(train(3318,6,0)),7), digit(tensor(train(3318,6,1)),3), digit(tensor(train(3318,6,2)),1), digit(tensor(train(3318,6,3)),8), digit(tensor(train(3318,6,4)),9), digit(tensor(train(3318,6,5)),6), none, none, none], [none, digit(tensor(train(3318,7,1)),2), none, none, none, none, digit(tensor(train(3318,7,6)),8), digit(tensor(train(3318,7,7)),1), none], [none, digit(tensor(train(3318,8,1)),8), digit(tensor(train(3318,8,2)),5), digit(tensor(train(3318,8,3)),3), digit(tensor(train(3318,8,4)),1), digit(tensor(train(3318,8,5)),2), digit(tensor(train(3318,8,6)),6), none, none]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, 9, X1, X2, 3, X3, 7, 6, 2]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 8, 7, 5, 9, X3, 4, 1]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 2, 6, 4, X4, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 4, 3, X2, X3, 1, X4, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, X1, 2, X2, 7, X3, 1, 9, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, 7, X1, X2, X3, 5, X4, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[7, 3, 1, 8, 9, 6, X1, X2, X3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 2, X2, X3, X4, X5, 8, 1, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, 5, 3, 1, 2, 6, X2, X3]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[5, 9, X1, X2, 3, X3, 7, 6, 2], [X4, X5, 8, 7, 5, 9, X6, 4, 1], [X7, X8, X9, 2, 6, 4, X10, X11, X12], [X13, 4, 3, X14, X15, 1, X16, X17, X18], [8, X19, 2, X20, 7, X21, 1, 9, X22], [1, 7, X23, X24, X25, 5, X26, X27, X28], [7, 3, 1, 8, 9, 6, X29, X30, X31], [X32, 2, X33, X34, X35, X36, 8, 1, X37], [X38, 8, 5, 3, 1, 2, 6, X39, X40]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[5, 9, X1, X2, 3, X3, 7, 6, 2], [X4, X5, 8, 7, 5, 9, X6, 4, 1], [X7, X8, X9, 2, 6, 4, X10, X11, X12], [X13, 4, 3, X14, X15, 1, X16, X17, X18], [8, X19, 2, X20, 7, X21, 1, 9, X22], [1, 7, X23, X24, X25, 5, X26, X27, X28], [7, 3, 1, 8, 9, 6, X29, X30, X31], [X32, 2, X33, X34, X35, X36, 8, 1, X37], [X38, 8, 5, 3, 1, 2, 6, X39, X40]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[5, 9, X1, X2, 3, X3, 7, 6, 2], [X4, X5, 8, 7, 5, 9, X6, 4, 1], [X7, X8, X9, 2, 6, 4, X10, X11, X12], [X13, 4, 3, X14, X15, 1, X16, X17, X18], [8, X19, 2, X20, 7, X21, 1, 9, X22], [1, 7, X23, X24, X25, 5, X26, X27, X28], [7, 3, 1, 8, 9, 6, X29, X30, X31], [X32, 2, X33, X34, X35, X36, 8, 1, X37], [X38, 8, 5, 3, 1, 2, 6, X39, X40]]]
# 1 "transpose/2: Called with Ls=~w" [[[5, 9, X1, X2, 3, X3, 7, 6, 2], [X4, X5, 8, 7, 5, 9, X6, 4, 1], [X7, X8, X9, 2, 6, 4, X10, X11, X12], [X13, 4, 3, X14, X15, 1, X16, X17, X18], [8, X19, 2, X20, 7, X21, 1, 9, X22], [1, 7, X23, X24, X25, 5, X26, X27, X28], [7, 3, 1, 8, 9, 6, X29, X30, X31], [X32, 2, X33, X34, X35, X36, 8, 1, X37], [X38, 8, 5, 3, 1, 2, 6, X39, X40]]]
# Iteration:  8 	s:276.8813 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[5, X1, X2, X3, 8, 1, 7, X4, X5], [9, X6, X7, 4, X8, 7, 3, 2, 8], [X9, 8, X10, 3, 2, X11, 1, X12, 5], [X13, 7, 2, X14, X15, X16, 8, X17, 3], [3, 5, 6, X18, 7, X19, 9, X20, 1], [X21, 9, 4, 1, X22, 5, 6, X23, 2], [7, X24, X25, X26, 1, X27, X28, 8, 6], [6, 4, X29, X30, 9, X31, X32, 1, X33], [2, 1, X34, X35, X36, X37, X38, X39, X40]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[5, 9, X1, X2, 3, X3, 7, 6, 2], [[X4, X5, 8, 7, 5, 9, X6, 4, 1], [X7, X8, X9, 2, 6, 4, X10, X11, X12], [X13, 4, 3, X14, X15, 1, X16, X17, X18], [8, X19, 2, X20, 7, X21, 1, 9, X22], [1, 7, X23, X24, X25, 5, X26, X27, X28], [7, 3, 1, 8, 9, 6, X29, X30, X31], [X32, 2, X33, X34, X35, X36, 8, 1, X37], [X38, 8, 5, 3, 1, 2, 6, X39, X40]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 5, 8]]
# 1 "" [[6, 4, 3, 9, 2, 1, 5, 8, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 9, 6, 8, 5, 2, 3, 4]]
# 1 "" [[7, 3, 1, 8, 9, 6, 4, 2, 5]]
# 1 "" [[9, 2, 6, 5, 4, 7, 8, 1, 3]]
# 1 "" [[4, 8, 5, 3, 1, 2, 6, 7, 9]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 5, 8]]
# 1 "" [[6, 4, 3, 9, 2, 1, 5, 8, 7]]
# 1 "" [[8, 5, 2, 6, 7, 3, 1, 9, 4]]
# 1 "" [[1, 7, 9, 4, 8, 5, 2, 3, 6]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 5, 8]]
# 1 "" [[9, 4, 3, 6, 2, 1, 5, 8, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 6, 9, 8, 5, 2, 3, 4]]
# 1 "" [[7, 3, 1, 8, 9, 6, 4, 2, 5]]
# 1 "" [[6, 2, 9, 5, 4, 7, 8, 1, 3]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 8, 5]]
# 1 "" [[6, 4, 3, 9, 8, 1, 2, 5, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 9, 6, 2, 5, 4, 3, 8]]
# 1 "" [[7, 3, 1, 8, 9, 6, 5, 2, 4]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 8, 5]]
# 1 "" [[6, 4, 3, 9, 8, 1, 5, 2, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 9, 6, 2, 5, 4, 3, 8]]
# 1 "" [[7, 3, 1, 8, 9, 6, 2, 5, 4]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 8, 5]]
# 1 "" [[9, 4, 3, 6, 8, 1, 2, 5, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 6, 9, 2, 5, 4, 3, 8]]
# 1 "" [[7, 3, 1, 8, 9, 6, 5, 2, 4]]
# 1 "printing solution" []
# 1 "" [[5, 9, 4, 1, 3, 8, 7, 6, 2]]
# 1 "" [[2, 6, 8, 7, 5, 9, 3, 4, 1]]
# 1 "" [[3, 1, 7, 2, 6, 4, 9, 8, 5]]
# 1 "" [[9, 4, 3, 6, 8, 1, 5, 2, 7]]
# 1 "" [[8, 5, 2, 4, 7, 3, 1, 9, 6]]
# 1 "" [[1, 7, 6, 9, 2, 5, 4, 3, 8]]
# 1 "" [[7, 3, 1, 8, 9, 6, 2, 5, 4]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# ...
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[X1, 1, 9, X2, 5, X3, 6, 3, 8], [[X4, X5, X6, 6, X7, X8, 7, 9, 2], [6, 2, 7, 9, X9, X10, X11, X12, X13], [7, 3, 8, 5, 1, 6, 9, X14, X15], [9, X16, X17, X18, X19, 7, X20, X21, 6], [X22, 6, X23, X24, X25, 9, X26, 7, 3], [8, X27, X28, 1, X29, 5, 2, 6, X30], [X31, 7, 1, X32, 6, 8, X33, X34, 9], [X35, X36, X37, 3, X38, X39, X40, 8, 5]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# 1 "printing solution" []
# 1 "" [[4, 1, 9, 7, 5, 2, 6, 3, 8]]
# 1 "" [[3, 8, 5, 6, 4, 1, 7, 9, 2]]
# 1 "" [[6, 2, 7, 9, 8, 3, 4, 5, 1]]
# 1 "" [[7, 3, 8, 5, 1, 6, 9, 2, 4]]
# 1 "" [[9, 5, 2, 4, 3, 7, 8, 1, 6]]
# 1 "" [[1, 6, 4, 8, 2, 9, 5, 7, 3]]
# 1 "" [[8, 4, 3, 1, 9, 5, 2, 6, 7]]
# 1 "" [[5, 7, 1, 2, 6, 8, 3, 4, 9]]
# 1 "" [[2, 9, 6, 3, 7, 4, 1, 8, 5]]
# 1 "puzzle_solve/1: Successfully solved puzzle" []
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[none, none, digit(tensor(train(1495,0,2)),9), none, none, digit(tensor(train(1495,0,5)),3), none, digit(tensor(train(1495,0,7)),5), none], [digit(tensor(train(1495,1,0)),8), none, none, none, digit(tensor(train(1495,1,4)),1), none, digit(tensor(train(1495,1,6)),9), none, none], [none, none, none, digit(tensor(train(1495,2,3)),8), digit(tensor(train(1495,2,4)),9), digit(tensor(train(1495,2,5)),6), none, digit(tensor(train(1495,2,7)),4), digit(tensor(train(1495,2,8)),7)], [digit(tensor(train(1495,3,0)),3), digit(tensor(train(1495,3,1)),2), digit(tensor(train(1495,3,2)),7), none, none, digit(tensor(train(1495,3,5)),5), digit(tensor(train(1495,3,6)),6), digit(tensor(train(1495,3,7)),1), none], [none, digit(tensor(train(1495,4,1)),9), digit(tensor(train(1495,4,2)),8), digit(tensor(train(1495,4,3)),6), none, none, none, digit(tensor(train(1495,4,7)),3), none], [digit(tensor(train(1495,5,0)),5), none, none, none, digit(tensor(train(1495,5,4)),3), none, none, none, none], [none, none, digit(tensor(train(1495,6,2)),1), digit(tensor(train(1495,6,3)),2), digit(tensor(train(1495,6,4)),6), digit(tensor(train(1495,6,5)),9), digit(tensor(train(1495,6,6)),4), digit(tensor(train(1495,6,7)),8), digit(tensor(train(1495,6,8)),3)], [none, digit(tensor(train(1495,7,1)),8), none, digit(tensor(train(1495,7,3)),3), digit(tensor(train(1495,7,4)),4), none, digit(tensor(train(1495,7,6)),7), digit(tensor(train(1495,7,7)),6), none], [digit(tensor(train(1495,8,0)),4), digit(tensor(train(1495,8,1)),3), digit(tensor(train(1495,8,2)),6), none, digit(tensor(train(1495,8,4)),5), digit(tensor(train(1495,8,5)),8), digit(tensor(train(1495,8,6)),2), none, none]]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 9, X3, X4, 3, X5, 5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[8, X1, X2, X3, 1, X4, 9, X5, X6]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, X3, 8, 9, 6, X4, 4, 7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[3, 2, 7, X1, X2, 5, 6, 1, X3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 9, 8, 6, X2, X3, X4, 3, X5]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[5, X1, X2, X3, 3, X4, X5, X6, X7]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 1, 2, 6, 9, 4, 8, 3]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 8, X2, 3, 4, X3, 7, 6, X4]]
# 1 "puzzle_image_rows/2: Built row => ~w" [[4, 3, 6, X1, 5, 8, 2, X2, X3]]
# 1 "puzzle_image_rows/2: Base case, no more rows." []
# 1 "puzzle_solve/1: ValueRows=~w" [[[X1, X2, 9, X3, X4, 3, X5, 5, X6], [8, X7, X8, X9, 1, X10, 9, X11, X12], [X13, X14, X15, 8, 9, 6, X16, 4, 7], [3, 2, 7, X17, X18, 5, 6, 1, X19], [X20, 9, 8, 6, X21, X22, X23, 3, X24], [5, X25, X26, X27, 3, X28, X29, X30, X31], [X32, X33, 1, 2, 6, 9, 4, 8, 3], [X34, 8, X35, 3, 4, X36, 7, 6, X37], [4, 3, 6, X38, 5, 8, 2, X39, X40]]]
# 1 "solveSudoku/3: Called with H=~w, W=~w, Sudoku=~w" [3, 3, [[X1, X2, 9, X3, X4, 3, X5, 5, X6], [8, X7, X8, X9, 1, X10, 9, X11, X12], [X13, X14, X15, 8, 9, 6, X16, 4, 7], [3, 2, 7, X17, X18, 5, 6, 1, X19], [X20, 9, 8, 6, X21, X22, X23, 3, X24], [5, X25, X26, X27, 3, X28, X29, X30, X31], [X32, X33, 1, 2, 6, 9, 4, 8, 3], [X34, 8, X35, 3, 4, X36, 7, 6, X37], [4, 3, 6, X38, 5, 8, 2, X39, X40]]]
# 1 "getProblem/3: Called with H=~w, W=~w, Rows=~w" [3, 3, [[X1, X2, 9, X3, X4, 3, X5, 5, X6], [8, X7, X8, X9, 1, X10, 9, X11, X12], [X13, X14, X15, 8, 9, 6, X16, 4, 7], [3, 2, 7, X17, X18, 5, 6, 1, X19], [X20, 9, 8, 6, X21, X22, X23, 3, X24], [5, X25, X26, X27, 3, X28, X29, X30, X31], [X32, X33, 1, 2, 6, 9, 4, 8, 3], [X34, 8, X35, 3, 4, X36, 7, 6, X37], [4, 3, 6, X38, 5, 8, 2, X39, X40]]]
# 1 "transpose/2: Called with Ls=~w" [[[X1, X2, 9, X3, X4, 3, X5, 5, X6], [8, X7, X8, X9, 1, X10, 9, X11, X12], [X13, X14, X15, 8, 9, 6, X16, 4, 7], [3, 2, 7, X17, X18, 5, 6, 1, X19], [X20, 9, 8, 6, X21, X22, X23, 3, X24], [5, X25, X26, X27, 3, X28, X29, X30, X31], [X32, X33, 1, 2, 6, 9, 4, 8, 3], [X34, 8, X35, 3, 4, X36, 7, 6, X37], [4, 3, 6, X38, 5, 8, 2, X39, X40]]]
# Iteration:  14 	s:220.3534 	Average Loss:  27.63102149963379
# 1 "transpose/2: Transposed ~w" [[[X1, 8, X2, 3, X3, 5, X4, X5, 4], [X6, X7, X8, 2, 9, X9, X10, 8, 3], [9, X11, X12, 7, 8, X13, 1, X14, 6], [X15, X16, 8, X17, 6, X18, 2, 3, X19], [X20, 1, 9, X21, X22, 3, 6, 4, 5], [3, X23, 6, 5, X24, X25, 9, X26, 8], [X27, 9, X28, 6, X29, X30, 4, 7, 2], [5, X31, 4, 1, 3, X32, 8, 6, X33], [X34, X35, 7, X36, X37, X38, 3, X39, X40]]]
# 1 "getBoxes/4: Called with H=~w, T=~w, BoxWidth=~w, BoxHeight=~w" [[X1, X2, 9, X3, X4, 3, X5, 5, X6], [[8, X7, X8, X9, 1, X10, 9, X11, X12], [X13, X14, X15, 8, 9, 6, X16, 4, 7], [3, 2, 7, X17, X18, 5, 6, 1, X19], [X20, 9, 8, 6, X21, X22, X23, 3, X24], [5, X25, X26, X27, 3, X28, X29, X30, X31], [X32, X33, 1, 2, 6, 9, 4, 8, 3], [X34, 8, X35, 3, 4, X36, 7, 6, X37], [4, 3, 6, X38, 5, 8, 2, X39, X40]], 3, 3]
# 1 "getSolution/2: Sudoku solved, but the garbage persists." []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 19
#      13 # If you have labeled cells (supervised approach):
#      14 #   You'd define something like SudokuCellDataset for labeled digit training
#      15 #   with queries digit(tensor(...), label). Then do train_model(...).
#      16
#      17 # For puzzle-level training or inference (unsupervised?), you can do:
#      18 loader = DataLoader(train_data, batch_size=1, shuffle=True)
# ---> 19 train_model(model, loader, 1, log_iter=1)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:200, in train_model(model, loader, stop_condition, **kwargs)
#     193 def train_model(
#     194     model: Model,
#     195     loader: DataLoader,
#     196     stop_condition: Union[int, StopCondition],
#     197     **kwargs
#     198 ) -> TrainObject:
#     199     train_object = TrainObject(model)
# --> 200     train_object.train(loader, stop_condition, **kwargs)
#     201     return train_object
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:128, in TrainObject.train(self, loader, stop_criterion, verbose, loss_function_name, with_negatives, log_iter, initial_test, **kwargs)
#     126     loss = self.get_loss_with_negatives(batch, loss_function)
#     127 else:
# --> 128     loss = self.get_loss(batch, loss_function)
#     129 self.accumulated_loss += loss
#     131 self.model.optimizer.step()
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:39, in TrainObject.get_loss(self, batch, backpropagate_loss)
#      32 """
#      33 Calculates and propagates the loss for a given batch of queries and loss function.
#      34 :param batch: The batch of queries.
#      35 :param backpropagate_loss:  The loss function. It should also perform the backpropagation.
#      36 :return: The average loss over the batch
#      37 """
#      38 total_loss = 0
# ---> 39 result = self.model.solve(batch)
#      40 for r in result:
#      41     self.timing[0] += r.ground_time / len(batch)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/model.py:117, in Model.solve(self, batch)
#     116 def solve(self, batch: Sequence[Query]) -> List[Result]:
# --> 117     return self.solver.solve(batch)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:86, in Solver.solve(self, batch)
#      84 self.engine.tensor_store.clear()
#      85 # Build ACs
# ---> 86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
#      88 result = [
#      89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:86, in <listcomp>(.0)
#      84 self.engine.tensor_store.clear()
#      85 # Build ACs
# ---> 86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
#      88 result = [
#      89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/utils/cache.py:52, in Cache.get(self, item)
#      51 def get(self, item: K) -> T:
# ---> 52     return self.first(item)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:71, in Solver.build_ac(self, q)
#      64 """
#      65 Builds the arithmetic circuit.
#      66 :param q: The query for which to build the arithmetic circuit.
#      67 :return: The arithmetic circuit for the given query.
#      68 """
#      69 start = time()
# ---> 71 ground = self.engine.ground(q, label=LogicFormula.LABEL_QUERY)
#      72 ground_time = time() - start
#      73 ac = ArithmeticCircuit(
#      74     ground, self.semiring, ground_time=ground_time, sdd_auto_gc=self.sdd_auto_gc
#      75 )
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/engines/exact_engine.py:147, in ExactEngine.ground(self, query, label, repeat, **kwargs)
#     145 if not self.model.solver.cache.cache:
#     146     query = query.substitute()
# --> 147 ground = self.engine.ground(db, query.query, label=label)
#     148 return ground
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine.py:336, in ClauseDBEngine.ground(self, db, term, target, label, **kwdargs)
#     333 else:
#     334     negated = False
# --> 336 target, results = self._ground(db, term, target, silent_fail=False, **kwdargs)
#     338 args_node = defaultdict(list)
#     339 for args, node_id in results:
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine.py:451, in ClauseDBEngine._ground(self, db, term, gp, silent_fail, assume_prepared, **kwdargs)
#     447         location = db.lineno(term.location)
#     448         self.debugger.call_create(
#     449             clause_node, term.functor, context, None, location
#     450         )
# --> 451     results = self.execute(
#     452         clause_node, database=db, target=gp, context=context, **kwdargs
#     453     )
#     454 except UnknownClauseInternal:
#     455     if silent_fail or self.unknown == self.UNKNOWN_FAIL:
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:441, in StackBasedEngine.execute(self, node_id, target, database, subcall, is_root, name, **kwdargs)
#     423 # We need to execute another node.
#     424 # if self.cycle_root is not None and context['parent'] < self.cycle_root.pointer:
#     425 #     print ('Cycle exhausted indeed:', len(actions) + 1)
#    (...)
#     430 #         (act, obj, args, context)]
#     431 # else:
#     432 try:
#     433     # Evaluate the next node.
#     434     # if exclude is not None and obj in exclude:
#    (...)
#     439     #     obj = self.pointer
#     440     # else:
# --> 441     next_actions = self.eval(obj, **context)
#     442     obj = self.pointer
#     443 except UnknownClauseInternal:
#     444     # An unknown clause was encountered.
#     445     # TODO why is this handled here?
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:126, in StackBasedEngine.eval(self, node_id, **kwdargs)
#     123         else:
#     124             raise UnknownClauseInternal()
# --> 126 return exec_func(node_id=node_id, node=node, **kwdargs)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:891, in StackBasedEngine.eval_clause(self, context, node, node_id, parent, transform, identifier, current_clause, **kwdargs)
#     888         return self.create_context(output, parent=result)
#     890     transform.addFunction(result_transform)
# --> 891     return self.eval(
#     892         node.child,
#     893         context=new_context,
#     894         parent=parent,
#     895         transform=transform,
#     896         current_clause=node_id,
#     897         identifier=identifier,
#     898         **kwdargs
#     899     )
#     900 except UnifyError:
#     901     # Call and clause head are not unifiable, just fail (complete without results).
#     902     return [complete(parent, identifier)]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:126, in StackBasedEngine.eval(self, node_id, **kwdargs)
#     123         else:
#     124             raise UnknownClauseInternal()
# --> 126 return exec_func(node_id=node_id, node=node, **kwdargs)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:834, in StackBasedEngine.eval_call(self, node_id, node, context, parent, transform, identifier, **kwdargs)
#     831 kwdargs["transform"] = transform
#     833 try:
# --> 834     return self.eval(
#     835         node.defnode, parent=parent, identifier=identifier, **kwdargs
#     836     )
#     837 except UnknownClauseInternal:
#     838     loc = kwdargs["database"].lineno(node.location)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:126, in StackBasedEngine.eval(self, node_id, **kwdargs)
#     123         else:
#     124             raise UnknownClauseInternal()
# --> 126 return exec_func(node_id=node_id, node=node, **kwdargs)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:699, in StackBasedEngine.eval_define(self, node, context, target, parent, identifier, transform, is_root, no_cache, **kwdargs)
#     685     return results_to_actions(
#     686         results,
#     687         self,
#    (...)
#     695         **kwdargs
#     696     )
#     697 else:
#     698     # Look up the results in the currently active nodes.
# --> 699     active_node = target._cache.getEvalNode(goal)
#     700     if active_node is not None:
#     701         # There is an active node.
#     702         if active_node.is_ground and active_node.results:
#     703             # If the node is ground, we can simply return the current result node.
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:1382, in DefineCache.getEvalNode(self, goal)
#    1381 def getEvalNode(self, goal):
# -> 1382     return self.__active.get(self._reindex_vars(goal))
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:1368, in DefineCache._reindex_vars(self, goal)
#    1366 def _reindex_vars(self, goal):
#    1367     ri = VarReindex()
# -> 1368     return goal[0], [substitute_simple(g, ri) for g in goal[1]]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:1368, in <listcomp>(.0)
#    1366 def _reindex_vars(self, goal):
#    1367     ri = VarReindex()
# -> 1368     return goal[0], [substitute_simple(g, ri) for g in goal[1]]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_unify.py:291, in substitute_simple(term, context)
#     289     return context[term]
#     290 else:
# --> 291     return term.apply(context)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:273, in Term.apply(self, subst)
#     270 new_stack = []
#     271 term_stack = []
# --> 273 while old_stack:
#     274     current = old_stack[-1].popleft()
#     275     if current is None or type(current) == int:
#
# KeyboardInterrupt:

# %%
# 4) Inference on a single puzzle
test_query = dataset.to_query(0)
result = model.solve([test_query])
print("Puzzle solution:", result)
# Out:
# Puzzle solution: [{digit(tensor(train_single_image(0)),5): tensor(0.8645, grad_fn=<SelectBackward0>)}]
# 1 "digit/2 => NN recognized => D=~w" 5
