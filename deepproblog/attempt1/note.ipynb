# %%
from typing import Iterator
import numpy as np
import os
import torch
from problog.logic import Term, Constant, list2term
from deepproblog.dataset import Dataset
from deepproblog.query import Query
import matplotlib.pyplot as plt
import sys

# %%
import torch
import torch.nn as nn

class MNIST_SudokuNet(nn.Module):
    def __init__(self):
        super(MNIST_SudokuNet, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 6, 5),
            nn.MaxPool2d(2, 2),
            nn.ReLU(True),
            nn.Conv2d(6, 16, 5),
            nn.MaxPool2d(2, 2),
            nn.ReLU(True),
        )
        # Only 9 outputs now
        self.classifier = nn.Sequential(
            nn.Linear(16*4*4, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, 9),   # 9 classes => digits 1..9
            nn.Softmax(dim=1),
        )

    def forward(self, x):
        x = self.encoder(x)                # 1×28×28 -> ...
        x = x.view(-1, 16 * 4 * 4)         
        x = self.classifier(x)             # -> 9 outputs 
        return x

# %%
class SudokuPuzzleDataset(Dataset):
    def __init__(self, subset: str, puzzle_path: str):
        self.subset = subset
        self.puzzle_files = sorted([f for f in os.listdir(puzzle_path) if f.endswith('.npy')])
        self.puzzles = []
        for fn in self.puzzle_files:
            puzzle = np.load(os.path.join(puzzle_path, fn), allow_pickle=True)
            # Keep puzzle[i][j] == None if empty
            # If not None, we treat it as a 28×28 image
            #   and normalize it (1..255 => /255)
            for i in range(9):
                for j in range(9):
                    if puzzle[i][j] is not None:
                        puzzle[i][j] = puzzle[i][j].astype(np.float32)/255.0
            self.puzzles.append(puzzle)

    def __len__(self):
        return len(self.puzzles)

    def __getitem__(self, item):
        """
        For the Prolog side, we only need to retrieve the actual image data 
        if the cell is not None. We'll handle that in 'to_query' as well.
        """
        # This method is used by the DeepProbLog model to fetch the image.
        # We'll just return a single cell's tensor to illustrate 
        # (not typically used if you do full puzzle queries).
        puzzle_index, row, col = item
        cell = self.puzzles[int(puzzle_index)][int(row)][int(col)]
        if cell is None:
            # Not returning an image for None cells
            raise ValueError("Attempted to retrieve an image for a None cell.")
        # print
        return torch.tensor(cell).unsqueeze(0)  # 1×28×28

    def to_query(self, index: int) -> Query:
        """
        Construct a query puzzle_solve(...) for the entire 9×9 puzzle.
        We'll produce a 9×9 list-of-lists:
          - If puzzle[i][j] is None => use Constant('none')
          - Else => Term('tensor', Term(self.subset, Constant(unique_id)))
        """
        puzzle = self.puzzles[index]
        # We'll create 9 rows of terms
        row_list_terms = []

        for i in range(9):
            col_terms = []
            for j in range(9):
                if puzzle[i][j] is None:
                    # Just an atom 'none'
                    col_terms.append(Constant('none'))
                else:
                    # A reference to the network input
                    col_terms.append(Term("tensor", Term(self.subset, Constant(index), Constant(i), Constant(j))))

            row_list_terms.append(list2term(col_terms))

        # puzzle_solve( [[...],[...],...] )
        query_term = Term("puzzle_solve", list2term(row_list_terms))
        # print("Query constructed", query_term)
        return Query(query_term)

# %%
import torch
from deepproblog.model import Model
from deepproblog.network import Network
from deepproblog.engines import ExactEngine
from deepproblog.dataset import DataLoader
from deepproblog.train import train_model

# %%
network = MNIST_SudokuNet()
net = Network(network, "mnist_net", batching=True)
net.optimizer = torch.optim.Adam(network.parameters(), lr=1e-3)

# 2) Create the model from 'sudoku_no_clpfd.pl'
model = Model("prolog3.pl", [net])
model.set_engine(ExactEngine(model))

# 3) Load the dataset
train_data = SudokuPuzzleDataset("train", "../../mnist_sudoku_generator/dataset/images/puzzles/train")
model.add_tensor_source("train", train_data)

# If you have labeled cells (supervised approach):
#   You'd define something like SudokuCellDataset for labeled digit training 
#   with queries digit(tensor(...), label). Then do train_model(...).

# For puzzle-level training or inference (unsupervised?), you can do:
loader = DataLoader(train_data, batch_size=1, shuffle=False)
train_model(model, loader, 1, log_iter=1)
# Out:
# Training  for 1 epoch(s)
# Epoch 1
# 1 "puzzle_solve/1: Called with ImageRows=~w" [[[none, none, tensor(train(0,0,2)), tensor(train(0,0,3)), tensor(train(0,0,4)), tensor(train(0,0,5)), none, none, none], [none, none, tensor(train(0,1,2)), none, tensor(train(0,1,4)), none, tensor(train(0,1,6)), tensor(train(0,1,7)), tensor(train(0,1,8))], [none, tensor(train(0,2,1)), tensor(train(0,2,2)), none, none, none, none, tensor(train(0,2,7)), tensor(train(0,2,8))], [tensor(train(0,3,0)), none, tensor(train(0,3,2)), none, tensor(train(0,3,4)), none, tensor(train(0,3,6)), none, tensor(train(0,3,8))], [none, none, tensor(train(0,4,2)), tensor(train(0,4,3)), tensor(train(0,4,4)), tensor(train(0,4,5)), tensor(train(0,4,6)), tensor(train(0,4,7)), none], [tensor(train(0,5,0)), tensor(train(0,5,1)), tensor(train(0,5,2)), none, none, tensor(train(0,5,5)), none, tensor(train(0,5,7)), tensor(train(0,5,8))], [none, none, tensor(train(0,6,2)), tensor(train(0,6,3)), none, none, none, none, none], [none, none, tensor(train(0,7,2)), none, none, tensor(train(0,7,5)), tensor(train(0,7,6)), tensor(train(0,7,7)), none], [none, tensor(train(0,8,1)), tensor(train(0,8,2)), none, tensor(train(0,8,4)), none, none, tensor(train(0,8,7)), tensor(train(0,8,8))]]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[none, none, tensor(train(0,0,2)), tensor(train(0,0,3)), tensor(train(0,0,4)), tensor(train(0,0,5)), none, none, none]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,0,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,0,3))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,0,4))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,0,5))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 1, 1, 1, 1, X3, X4, X5]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[none, none, tensor(train(0,1,2)), none, tensor(train(0,1,4)), none, tensor(train(0,1,6)), tensor(train(0,1,7)), tensor(train(0,1,8))]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,1,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,1,4))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,1,6))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,1,7))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,1,8))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 1, X3, 1, X4, 1, 1, 1]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[none, tensor(train(0,2,1)), tensor(train(0,2,2)), none, none, none, none, tensor(train(0,2,7)), tensor(train(0,2,8))]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,2,1))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,2,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,2,7))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,2,8))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, 1, 1, X2, X3, X4, X5, 1, 1]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[tensor(train(0,3,0)), none, tensor(train(0,3,2)), none, tensor(train(0,3,4)), none, tensor(train(0,3,6)), none, tensor(train(0,3,8))]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,3,0))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,3,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,3,4))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,3,6))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,3,8))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "puzzle_image_rows/2: Built row => ~w" [[1, X1, 1, X2, 1, X3, 1, X4, 1]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[none, none, tensor(train(0,4,2)), tensor(train(0,4,3)), tensor(train(0,4,4)), tensor(train(0,4,5)), tensor(train(0,4,6)), tensor(train(0,4,7)), none]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,3))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,4))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,5))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,6))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,4,7))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "puzzle_image_rows/2: Built row => ~w" [[X1, X2, 1, 1, 1, 1, 1, 1, X3]]
# 1 "puzzle_image_rows/2: Building row from ~w" [[tensor(train(0,5,0)), tensor(train(0,5,1)), tensor(train(0,5,2)), none, none, tensor(train(0,5,5)), none, tensor(train(0,5,7)), tensor(train(0,5,8))]]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,0))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,1))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,2))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,5))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,7))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# 1 "digit/2 => calling NN for X=~w" [tensor(train(0,5,8))]
# 1 "digit/2 => NN recognized => D=~w" [1]
# 1 "digit/2 => NN recognized => D=~w" [2]
# 1 "digit/2 => NN recognized => D=~w" [3]
# 1 "digit/2 => NN recognized => D=~w" [4]
# 1 "digit/2 => NN recognized => D=~w" [5]
# 1 "digit/2 => NN recognized => D=~w" [6]
# 1 "digit/2 => NN recognized => D=~w" [7]
# 1 "digit/2 => NN recognized => D=~w" [8]
# 1 "digit/2 => NN recognized => D=~w" [9]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 19
#      13 # If you have labeled cells (supervised approach):
#      14 #   You'd define something like SudokuCellDataset for labeled digit training
#      15 #   with queries digit(tensor(...), label). Then do train_model(...).
#      16
#      17 # For puzzle-level training or inference (unsupervised?), you can do:
#      18 loader = DataLoader(train_data, batch_size=1, shuffle=False)
# ---> 19 train_model(model, loader, 1, log_iter=1)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:200, in train_model(model, loader, stop_condition, **kwargs)
#     193 def train_model(
#     194     model: Model,
#     195     loader: DataLoader,
#     196     stop_condition: Union[int, StopCondition],
#     197     **kwargs
#     198 ) -> TrainObject:
#     199     train_object = TrainObject(model)
# --> 200     train_object.train(loader, stop_condition, **kwargs)
#     201     return train_object
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:128, in TrainObject.train(self, loader, stop_criterion, verbose, loss_function_name, with_negatives, log_iter, initial_test, **kwargs)
#     126     loss = self.get_loss_with_negatives(batch, loss_function)
#     127 else:
# --> 128     loss = self.get_loss(batch, loss_function)
#     129 self.accumulated_loss += loss
#     131 self.model.optimizer.step()
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/train.py:39, in TrainObject.get_loss(self, batch, backpropagate_loss)
#      32 """
#      33 Calculates and propagates the loss for a given batch of queries and loss function.
#      34 :param batch: The batch of queries.
#      35 :param backpropagate_loss:  The loss function. It should also perform the backpropagation.
#      36 :return: The average loss over the batch
#      37 """
#      38 total_loss = 0
# ---> 39 result = self.model.solve(batch)
#      40 for r in result:
#      41     self.timing[0] += r.ground_time / len(batch)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/model.py:117, in Model.solve(self, batch)
#     116 def solve(self, batch: Sequence[Query]) -> List[Result]:
# --> 117     return self.solver.solve(batch)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:86, in Solver.solve(self, batch)
#      84 self.engine.tensor_store.clear()
#      85 # Build ACs
# ---> 86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
#      88 result = [
#      89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:86, in <listcomp>(.0)
#      84 self.engine.tensor_store.clear()
#      85 # Build ACs
# ---> 86 acs: List[ArithmeticCircuit] = [self.cache.get(q) for q in batch]
#      87 # Evaluate ACs. Evaluate networks if necessary
#      88 result = [
#      89     ac.evaluate(self.model, batch[i].substitution) for i, ac in enumerate(acs)
#      90 ]
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/utils/cache.py:52, in Cache.get(self, item)
#      51 def get(self, item: K) -> T:
# ---> 52     return self.first(item)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/solver.py:71, in Solver.build_ac(self, q)
#      64 """
#      65 Builds the arithmetic circuit.
#      66 :param q: The query for which to build the arithmetic circuit.
#      67 :return: The arithmetic circuit for the given query.
#      68 """
#      69 start = time()
# ---> 71 ground = self.engine.ground(q, label=LogicFormula.LABEL_QUERY)
#      72 ground_time = time() - start
#      73 ac = ArithmeticCircuit(
#      74     ground, self.semiring, ground_time=ground_time, sdd_auto_gc=self.sdd_auto_gc
#      75 )
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/deepproblog/engines/exact_engine.py:147, in ExactEngine.ground(self, query, label, repeat, **kwargs)
#     145 if not self.model.solver.cache.cache:
#     146     query = query.substitute()
# --> 147 ground = self.engine.ground(db, query.query, label=label)
#     148 return ground
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine.py:336, in ClauseDBEngine.ground(self, db, term, target, label, **kwdargs)
#     333 else:
#     334     negated = False
# --> 336 target, results = self._ground(db, term, target, silent_fail=False, **kwdargs)
#     338 args_node = defaultdict(list)
#     339 for args, node_id in results:
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine.py:451, in ClauseDBEngine._ground(self, db, term, gp, silent_fail, assume_prepared, **kwdargs)
#     447         location = db.lineno(term.location)
#     448         self.debugger.call_create(
#     449             clause_node, term.functor, context, None, location
#     450         )
# --> 451     results = self.execute(
#     452         clause_node, database=db, target=gp, context=context, **kwdargs
#     453     )
#     454 except UnknownClauseInternal:
#     455     if silent_fail or self.unknown == self.UNKNOWN_FAIL:
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:470, in StackBasedEngine.execute(self, node_id, target, database, subcall, is_root, name, **kwdargs)
#     464     raise InvalidEngineState(
#     465         "Invalid node at given pointer: %s" % obj
#     466     )
#     468 if act == "r":
#     469     # A new result was received.
# --> 470     cleanup, next_actions = exec_node.new_result(
#     471         *args, **context
#     472     )
#     473 elif act == "c":
#     474     # A completion message was received.
#     475     cleanup, next_actions = exec_node.complete(*args, **context)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/eval_nodes.py:488, in EvalDefine.new_result(self, result, node, source, is_last)
#     486 assert not self.results.collapsed
#     487 res = self.engine._fix_context(result)
# --> 488 self.results[res] = node
#     489 if is_last:
#     490     return self.complete(source)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/eval_nodes.py:29, in ResultSet.__setitem__(self, result, node)
#      28 def __setitem__(self, result, node):
# ---> 29     index = self.index.get(result)
#      30     if index is None:
#      31         index = len(self.results)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/engine_stack.py:1069, in FixedContext.__hash__(self)
#    1068 def __hash__(self):
# -> 1069     return tuple.__hash__(self) + hash(self.state)
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:799, in Term.__hash__(self)
#     796                 else:
#     797                     break
# --> 799     self.__hash = hash(tuple(list_hash))
#     801     # self.__hash = hash((self.__functor, self.__arity, firstarg, self._list_length()))
#     802 return self.__hash
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:765, in Term.__hash__(self)
#     762 def __hash__(self):
#     763     if self.__hash is None:
#     764         # CG
# --> 765         list_hash = [self.__functor, self.__arity, self._list_length()]
#     767         def get_arg_len(a):
#     768             if isinstance(a, list):
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:648, in Term._list_length(self)
#     645 l = 0
#     646 current = self
#     647 while (
# --> 648     not is_variable(current)
#     649     and current.functor == "."
#     650     and current.arity == 2
#     651 ):
#     652     if current._cache_list_length is not None:
#     653         return l + current._cache_list_length
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:167, in is_variable(term)
#     161 def is_variable(term):
#     162     """Test whether a Term represents a variable.
#     163
#     164     :param term: term to check
#     165     :return: True if the expression is a variable
#     166     """
# --> 167     return term is None or type(term) == int or term.is_var()
#
# File ~/warsztatAI2/venvs/prolog-venv/lib/python3.10/site-packages/problog/logic.py:586, in Term.is_var(self)
#     572     """Creates a new Term with the same functor and arguments but with a different probability.
#     573
#     574     :param p: new probability (None clears the probability)
#     575     :return: copy of the Term
#     576     """
#     577     return self.__class__(
#     578         self.functor,
#     579         *self.args,
#    (...)
#     583         location=self.location
#     584     )
# --> 586 def is_var(self):
#     587     """Checks whether this Term represents a variable."""
#     588     return False
#
# KeyboardInterrupt:

# %%
# 4) Inference on a single puzzle
test_query = train_data.to_query(0)
result = model.solve([test_query])[0]
print("Puzzle solution:", result)
# Out:
# Puzzle solution: {puzzle_solve([[none, none, tensor(train(0,0,2)), tensor(train(0,0,3)), tensor(train(0,0,4)), tensor(train(0,0,5)), none, none, none], [none, none, tensor(train(0,1,2)), none, tensor(train(0,1,4)), none, tensor(train(0,1,6)), tensor(train(0,1,7)), tensor(train(0,1,8))], [none, tensor(train(0,2,1)), tensor(train(0,2,2)), none, none, none, none, tensor(train(0,2,7)), tensor(train(0,2,8))], [tensor(train(0,3,0)), none, tensor(train(0,3,2)), none, tensor(train(0,3,4)), none, tensor(train(0,3,6)), none, tensor(train(0,3,8))], [none, none, tensor(train(0,4,2)), tensor(train(0,4,3)), tensor(train(0,4,4)), tensor(train(0,4,5)), tensor(train(0,4,6)), tensor(train(0,4,7)), none], [tensor(train(0,5,0)), tensor(train(0,5,1)), tensor(train(0,5,2)), none, none, tensor(train(0,5,5)), none, tensor(train(0,5,7)), tensor(train(0,5,8))], [none, none, tensor(train(0,6,2)), tensor(train(0,6,3)), none, none, none, none, none], [none, none, tensor(train(0,7,2)), none, none, tensor(train(0,7,5)), tensor(train(0,7,6)), tensor(train(0,7,7)), none], [none, tensor(train(0,8,1)), tensor(train(0,8,2)), none, tensor(train(0,8,4)), none, none, tensor(train(0,8,7)), tensor(train(0,8,8))]]): 0.0}
